# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaRustagi10/contextualized-topic-models-ssl/blob/main/ZeroshotTM_For_Same_Script_Languages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zero-shot Cross-Lingual Topic Modeling For Same Script Languages
# > Do conxtextualized TM tackle zero-shot cross-lingual topic modeling better on same script languages?
#
# We use 4000 documents as training and consider randomly sampled 800 documents as the test set. We collect the 800 respective instances in [LANGUAGES].
#
# First, we use IndicBERT to generate multilingual embeddings as the input of the model. Then we evaluate multilingual topic predictions on the multilingual abstracts in test set.

# %%
# Install the contextualized topic model library
# %%capture
# !pip install -U contextualized_topic_models

# %%
# %%capture
# !pip install pyldavis
# !pip install wget
# !pip install head
# !nvidia-smi

# %%
# Imports
from contextualized_topic_models.models.ctm import ZeroShotTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import  WhiteSpacePreprocessingStopwords
import pickle

# %% [markdown]
# ## Data
#
# ###**Building PMIndia Corpus**
#
# Below contains the code for creating a parallel corpus from the website of the Indian Prime Minister (www.pmindia.gov.in).
#
# We combine each speech document into one, for every language. Datasets are downloaded from [Statistical Machine Translation](https://data.statmt.org/pmindia/v1/monolingual/).

# %% [markdown]
# *Downloading Dataset*

# %%
# Imports
import urllib
import wget
import pandas as pd
import os

# Download PMIndia Datasets
FILES_DIR = os.getcwd() # REPLACE WITH YOUR DIRECTORY IF YOU PREFER DOWNLOADING IN SPECIFIC DIRECTORY
LINK = "https://drive.google.com/u/0/uc?id=1IqH2XQFw1XHPT2Sh_Yz3LnrMEVqS8oef&export=download"  # LINK TO PMINDIA FILE LOCATION
FILE_PATH = os.getcwd() + "/" + wget.download(LINK) # PATH TO DOWNLOADS

pmindia_list = pd.read_csv(FILE_PATH, sep = ",",  names = ["lang", "link"], engine = "python" )['link']
pmindia_list = [FILES_DIR + "/" + wget.download(link.strip(" ")) for link in pmindia_list]

# %%
# Build directory to store speech files
# %%bash
mkdir parallel_speeches
cd parallel_speeches

# %%
# Files stored in content directory
# Data will need to be re-downloaded if a session closes
''' Following script will download parallel corpus into new directory named parallel_speeches.
Each folder in parallel_speeches contains pmindia speeches in indic language identified by their ISO code.

For e.g.
parallel_speeches/as/ contains speeches in Assamese.
parallel_speeches/hi contains speeches in Hindi.
'''
import tarfile
import os

FILES_DIR = os.getcwd() # REPLACE WITH DIRECTORY OF FILES
STORE_FILES_HERE = os.getcwd() + "/parallel_speeches" # STORE EXTRACTED FILES HERE

for fname in pmindia_list:
    tar = tarfile.open(fname, "r:gz") # unzip file
    tar.extractall(STORE_FILES_HERE)    
    foldername = fname[fname.rfind('.tgz')-2: fname.rfind('.tgz')] # get folder name
    os.rename(STORE_FILES_HERE + "/split", STORE_FILES_HERE + "/" + foldername) # rename default split folder to language name
    tar.close()

# %% [markdown]
# *Get Parallel Speeches*

# %%
import glob # SEEK FILES FROM ABOVE FOR DOWNLOAD
FOLDERS_DIR = os.getcwd() + "/parallel_speeches"  # DIRECTORY FOR SAVING PARALLEL SPEECHES

# Stores list of speeches in dictionary keyed by ISO language name
SPEECHES_IN_LANGS = {languagefolder[-2:] : sorted(list(glob.glob(languagefolder + "/*.txt")))[3:] for languagefolder in glob.glob(FOLDERS_DIR + "/*")}

# %%
# Get file names to find common test corpus (set of files common between all languages)
STRIP_INDEX = SPEECHES_IN_LANGS['as'][0].index('as') + len('as/')   # GET LANGUAGE ISO CODE

filenames = {}
for lang in SPEECHES_IN_LANGS.keys():
  temp = [item[STRIP_INDEX:] for item in SPEECHES_IN_LANGS[lang]]
  filenames[lang] = temp

# %% [markdown]
# *Combine Parallel Speeches Into Corpus*

# %%
# Setting seed for reproducibility
import random
random.seed(210)

# Select 800 random corpus
sample_corpus = sorted(random.sample(list(set.intersection(*map(set, filenames.values()))), 800))
sample_corpus
# Out:
# ['15th-edition-of-pravasi-bharatiya-diwas-inaugurated-by-pm-in-varanasi.txt',
#  'ambassador-ms-nikki-haley-united-states-permanent-representative-to-the-united-nations-calls-on-pm.txt',
#  'anganwadi-workers-from-across-the-country-call-on-pm.txt',
#  'asha-representatives-from-across-the-country-call-on-pm.txt',
#  'beneficiaries-of-pradhan-mantri-mudra-yojana-share-their-success-stories-during-interaction-with-pm.txt',
#  'beneficiaries-of-ujjwala-yojana-interact-with-pm.txt',
#  'boost-to-indias-space-program.txt',
#  'cabinet-apprised-of-agreement-between-india-and-uzbekistan-on-cooperation-in-the-field-of-science-technology-and-innovation.txt',
#  'cabinet-apprised-of-an-mou-signed-between-india-and-sri-lanka-for-promoting-cooperation-in-the-field-of-information-technology-and-electronics.txt',
#  'cabinet-apprised-of-framework-agreement-between-india-and-sao-tome-principe-for-cooperation-in-the-exploration-and-uses-of-outer-space-for-peaceful-purposes.txt',
#  'cabinet-apprised-of-implementing-arrangement-between-india-and-france-on-cooperation-on-maritime-awareness-mission.txt',
#  'cabinet-apprised-of-jointly-issue-of-postage-stamps-between-india-and-canada.txt',
#  'cabinet-apprised-of-mou-between-india-and-morocco-on-cooperation-in-the-area-of-cyber-security.txt',
#  'cabinet-apprised-of-progress-under-nhm-and-decisions-of-empowered-programme-committee-and-mission-steering-group-of-nhm.txt',
#  'cabinet-apprised-of-the-agreement-between-india-and-denmark-on-cooperation-in-the-field-of-science-technology-and-innovation.txt',
#  'cabinet-apprised-of-the-mou-between-atal-innovation-mission-india-and-fund-talent-and-success.txt',
#  'cabinet-apprised-of-the-mou-between-india-and-angola-for-promoting-bilateral-cooperation-in-the-field-of-electronics-and-it.txt',
#  'cabinet-apprised-of-the-mou-between-india-and-denmark-for-cooperation-in-the-fields-of-animal-husbandry-and-dairying.txt',
#  'cabinet-apprised-of-the-mou-between-india-and-italy-on-cooperation-in-the-field-of-renewable-energy.txt',
#  'cabinet-apprised-of-the-mou-between-india-and-south-korea-for-enhancing-cooperation-in-applied-science-and-industrial-technology.txt',
#  'cabinet-apprised-of-two-bilateral-mous-between-india-and-cuba-and-india-and-korea-in-the-area-of-biotechnology.txt',
#  'cabinet-approves-abolition-of-institution-of-income-tax-ombudsman-and-indirect-tax-ombudsman.txt',
#  'cabinet-approves-accession-to-the-protocol-under-who-framework-convention-on-tobacco-control.txt',
#  'cabinet-approves-accession-to-wipo-copyright-treaty-1996-and-wipo-performance-and-phonograms-treaty-1996.txt',
#  'cabinet-approves-agreement-between-india-and-algeria-on-cooperation-in-the-field-of-space-sciences-technologies-and-applications.txt',
#  'cabinet-approves-agreement-between-india-and-belarus-on-scientific-and-technological-cooperation-for-mutual-benefit-in-the-areas-of-science-technology-agriculture-etc.txt',
#  'cabinet-approves-agreement-between-india-and-france-on-technical-cooperation-in-the-field-of-sustainable-urban-development.txt',
#  'cabinet-approves-agreement-between-india-and-peru.txt',
#  'cabinet-approves-agreement-between-india-and-philippines-on-co-operation-and-mutual-assistance-in-customs-matters.txt',
#  'cabinet-approves-agreement-between-india-and-uzbekistan-on-cooperation-in-health-and-medical-science.txt',
#  'cabinet-approves-agreement-on-the-facilitation-of-visa-arrangements-signed-between-india-and-maldives.txt',
#  'cabinet-approves-amendment-of-the-jallianwala-bagh-national-memorial-act-1951.txt',
#  'cabinet-approves-amendment-to-the-trade-unions-act-1926-to-make-provisions-regarding-recognition-of-trade-unions.txt',
#  'cabinet-approves-amendments-in-fdi-policy.txt',
#  'cabinet-approves-appointment-of-adjudicating-authority-and-establishment-of-appellate-tribunal-under-prohibition-of-benami-property-transactions-act-1988.txt',
#  'cabinet-approves-appointment-of-second-national-judicial-pay-commission-for-subordinate-judiciary-in-the-country.txt',
#  'cabinet-approves-between-india-and-morocco-on-india-morocco-cooperation-in-renewable-energy.txt',
#  'cabinet-approves-bhopal-metro-rail-project-comprising-two-corridors.txt',
#  'cabinet-approves-bilateral-swap-arrangement-between-india-and-japan.txt',
#  'cabinet-approves-cadre-review-and-formation-of-group-a-service-of-the-technical-cadre-of-peso-in-the-name-of-ipess.txt',
#  'cabinet-approves-cadre-review-of-group-a-executive-cadre-of-central-industrial-security-force.txt',
#  'cabinet-approves-closure-of-national-jute-manufactures-corporation-ltd-and-its-subsidiary-birds-jute-exports-ltd.txt',
#  'cabinet-approves-coastal-regulation-zone-crz-notification-2018.txt',
#  'cabinet-approves-commemoration-of-the-550th-birth-anniversary-of-shri-guru-nanak-devji.txt',
#  'cabinet-approves-concession-agreements-land-lease-agreements.txt',
#  'cabinet-approves-construction-and-operationalisation-of-100-bedded-general-hospital-at-najafgarh-new-delhi.txt',
#  'cabinet-approves-continuation-of-nlcpr-scheme-for-north-east-till-march-2020.txt',
#  'cabinet-approves-continuation-of-pradhan-mantri-jandhan-yojana.txt',
#  'cabinet-approves-continuation-of-rastriya-yuva-sashaktikaran-karyakram-scheme-for-the-period-2017-18-to-2019-2020.txt',
#  'cabinet-approves-continuation-of-the-centrally-sponsored-scheme-to-improve-judiciary-infrastructure.txt',
#  'cabinet-approves-continuation-of-the-scheme-on-indian-institute-of-corporate-affairs-beyond-the-12th-plan-period.txt',
#  'cabinet-approves-creation-of-national-testing-agency-to-conduct-entrance-examinations-for-higher-educational-institutions.txt',
#  'cabinet-approves-creation-of-one-post-each-of-vice-chairperson-and-member-in-the-national-commission-for-safai-karamcharis.txt',
#  'cabinet-approves-creation-of-one-post-of-director-for-new-aiims-at-rae-bareli-gorakhpur-bathinda-guwahati-bilaspur-and-deoghar.txt',
#  'cabinet-approves-creation-of-post-of-technical-member-in-sat-mumbai.txt',
#  'cabinet-approves-creation-of-the-national-bench-of-the-goods-and-services-tax-appellate-tribunal-gstat.txt',
#  'cabinet-approves-creation-of-the-post-of-vice-chancellor-for-national-rail-transport-institute-deemed-to-be-university-set-up-in-vadodara-gujarat.txt',
#  'cabinet-approves-creation-of-two-posts-equivalent-to-joint-secretary-level-in-the-interpreters-cadre-of-the-ministry-of-external-affairs.txt',
#  'cabinet-approves-declaration-of-schedules-areas-in-respect-of-rajasthan-under-fifth-schedule-to-the-constitution-of-india.txt',
#  'cabinet-approves-deputation-of-group-a-officers-of-dot-and-other-ministries-with-telecommunication-and-it-background-to-tcil.txt',
#  'cabinet-approves-development-of-exhibition-cum-convention-centre-at-dwarka-new-delhi.txt',
#  'cabinet-approves-dna-technology-use-and-application-regulation-bill-2018.txt',
#  'cabinet-approves-doubling-of-investment-limit-for-senior-citizens-from-rs-7-5-lakh-to-rs-15-lakh-under-pmvvy.txt',
#  'cabinet-approves-enhancement-of-age-of-superannuation-of-general-duty-medical-officers-specialist-grade-doctors-and-teaching-medical-faculty-working-in-bhopal-memorial-hospital-and-research-centre-b.txt',
#  'cabinet-approves-establishment-and-operationalisation-of-permanent-campuses-of-the-iisers-at-tirupati-and-berhampur.txt',
#  'cabinet-approves-establishment-and-operationalization-of-permanent-campus-of-seven-new-iims.txt',
#  'cabinet-approves-establishment-of-additional-6-5mmt-strategic-petroleum-reserves-at-chandikhol-in-odisha-and-at-padur-karnataka.txt',
#  'cabinet-approves-establishment-of-national-institute-of-mental-health-rehabilitation-at-bhopal.txt',
#  'cabinet-approves-establishment-of-national-institute-of-mental-health-rehabilitation-in-sehore-district-instead-of-bhopal.txt',
#  'cabinet-approves-establishment-of-rashtriya-kamdhenu-aayog-for-conservation-protection-and-development-of-cows-and-their-progeny.txt',
#  'cabinet-approves-establishment-of-two-new-aiims-at-tamil-nadu-telangana-under-pradhan-mantri-swasthya-suraksha-yojana.txt',
#  'cabinet-approves-exemption-from-charging-commercial-rates-for-the-plot-of-land-allotted-to-the-high-commission-of-fiji-in-new-delhi.txt',
#  'cabinet-approves-expenditure-sanction-for-integrated-e-filing-and-centralized-processing-centre-2-0-project.txt',
#  'cabinet-approves-extension-of-concessional-financing-scheme-cfs-to-support-indian-entities-bidding-for-strategically-important-infrastructure-projects-abroad.txt',
#  'cabinet-approves-extension-of-delhi-metro-corridor-from-dilshad-garden-to-new-bus-adda-ghaziabad.txt',
#  'cabinet-approves-extension-of-delhi-metro-corridor-from-noida-city-centre-to-sector-62-noida-uttar-pradesh.txt',
#  'cabinet-approves-extension-of-scheme-of-recapitalization-of-regional-rural-banks-upto-2019-20.txt',
#  'cabinet-approves-extension-of-tenure-of-commission-constituted-to-examine-sub-categorization-within-obcs-in-central-list.txt',
#  'cabinet-approves-extension-of-the-term-of-the-commission-to-examine-the-issue-of-sub-categorization-of-other-backward-classes-in-the-central-list-till-31st-may-2019.txt',
#  'cabinet-approves-extension-of-the-term-of-the-commission-to-examine-the-issue-of-sub-categorization-of-other-backward-classes-in-the-central-list.txt',
#  'cabinet-approves-financial-assistance-worth-rs-825-crore-for-relining-of-sirhind-feeder-canal-and-relining-of-rajasthan-feeder-canal.txt',
#  'cabinet-approves-first-ever-three-way-merger-in-indian-banking-with-amalgamation-of-vijaya-dena-and-bank-of-baroda.txt',
#  'cabinet-approves-fixed-term-for-chairperson-and-members-of-the-national-trust.txt',
#  'cabinet-approves-high-level-committee-to-implement-clause-6-of-assam-accord-several-longstanding-demands-of-bodos-also-approved.txt',
#  'cabinet-approves-implementation-of-ccea-decision-on-closure-of-tungabhadra-steel-products-limited.txt',
#  'cabinet-approves-implementation-of-shahpurkandi-dam-national-project-on-river-ravi-in-punjab.txt',
#  'cabinet-approves-increasing-of-government-ownership-in-gst-network-and-change-in-the-existing-structure-with-transitional-plan.txt',
#  'cabinet-approves-indias-membership-for-european-bank-for-reconstruction-development.txt',
#  'cabinet-approves-indore-metro-rail-project-comprising-ring-line-bengali-square-vijay-nagar-bhawarsala-airport-patasia-bengali-square.txt',
#  'cabinet-approves-introduction-of-registration-of-marriage-of-nri-bill-2019.txt',
#  'cabinet-approves-joint-interpretative-declaration-between-india-and-colombia-regarding-the-agreement-for-the-promotion-and-protection-of-investments.txt',
#  'cabinet-approves-joint-issue-of-postage-stamp-between-india-and-south-africa.txt',
#  'cabinet-approves-long-term-agreements-for-supply-of-iron-ore-to-japan-and-south-korea-through-mmtc-limited.txt',
#  'cabinet-approves-measures-to-promote-hydro-power-sector.txt',
#  'cabinet-approves-memorandum-of-cooperation-between-india-and-finland-on-environmental-cooperation.txt',
#  'cabinet-approves-memorandum-of-cooperation-between-india-and-japan-in-the-field-of-healthcare-and-wellness.txt',
#  'cabinet-approves-memorandum-of-cooperation-moc-between-india-and-the-japan-in-the-field-of-healthcare-and-wellness.txt',
#  'cabinet-approves-memorandum-of-understanding-between-india-and-kuwait-for-cooperation-on-the-recruitment-of-domestic-workers.txt',
#  'cabinet-approves-moc-between-india-and-japan-in-the-field-of-environmental-cooperation.txt',
#  'cabinet-approves-moc-between-india-and-japan-in-the-field-of-food-processing-industry.txt',
#  'cabinet-approves-monetization-of-3-70-acres-of-land-at-pragati-maidan-by-itjpo.txt',
#  'cabinet-approves-mou-among-brics-nations-on-environmental-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-bahrain-on-cooperation-in-the-field-of-healthcare.txt',
#  'cabinet-approves-mou-between-india-and-belgium-on-cooperation-in-the-field-of-icte.txt',
#  'cabinet-approves-mou-between-india-and-brunei-darussalam-in-the-field-of-space-research-science-and-applications.txt',
#  'cabinet-approves-mou-between-india-and-canada-for-cooperation-in-the-field-of-science-technology.txt',
#  'cabinet-approves-mou-between-india-and-denmark-on-food-safety-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-denmark-on-technical-cooperation-in-the-field-of-sustainable-and-smart-urban-development.txt',
#  'cabinet-approves-mou-between-india-and-egypt-on-cooperation-in-the-field-of-agriculture-allied-sectors.txt',
#  'cabinet-approves-mou-between-india-and-election-management-bodies-of-namibia-and-panama.txt',
#  'cabinet-approves-mou-between-india-and-finland-in-the-field-of-biotechnology.txt',
#  'cabinet-approves-mou-between-india-and-finland-on-cooperation-in-the-field-of-peaceful-uses-of-outer-space.txt',
#  'cabinet-approves-mou-between-india-and-france-in-the-field-of-energy-efficiency-energy-conservation.txt',
#  'cabinet-approves-mou-between-india-and-france-in-the-field-of-new-and-renewable-energy.txt',
#  'cabinet-approves-mou-between-india-and-germany-on-cooperation-in-the-field-of-civil-aviation.txt',
#  'cabinet-approves-mou-between-india-and-indonesia-on-cooperation-in-the-field-of-pharmaceutical-products-pharmaceutical-substances-biological-product-and-cosmetics-regulatory-functions.txt',
#  'cabinet-approves-mou-between-india-and-indonesia-on-health-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-indonesia-on-scientific-and-technological-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-iran-for-cooperation-in-the-field-of-agriculture-and-allied-sectors.txt',
#  'cabinet-approves-mou-between-india-and-iran-on-cooperation-in-the-field-of-health-and-medicine.txt',
#  'cabinet-approves-mou-between-india-and-israel-on-cooperation-in-the-oil-and-gas-sector.txt',
#  'cabinet-approves-mou-between-india-and-japan-on-development-of-advanced-model-single-window.txt',
#  'cabinet-approves-mou-between-india-and-korea-on-trade-remedy-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-lebanon-for-cooperation-in-the-field-of-agriculture-and-allied-sectors.txt',
#  'cabinet-approves-mou-between-india-and-malaysia-for-mutual-cooperation-in-the-field-of-company-secretaryship.txt',
#  'cabinet-approves-mou-between-india-and-maldives-for-establishing-mutual-cooperation-to-improve-the-ecosystems-for-agribusiness.txt',
#  'cabinet-approves-mou-between-india-and-morocco-for-cooperation-in-the-peaceful-uses-of-outer-space.txt',
#  'cabinet-approves-mou-between-india-and-morocco-for-setting-up-of-a-joint-working-group-on-counter-terrorism.txt',
#  'cabinet-approves-mou-between-india-and-morocco-in-the-field-of-mining-and-geology.txt',
#  'cabinet-approves-mou-between-india-and-morocco-in-the-legal-field.txt',
#  'cabinet-approves-mou-between-india-and-norway-on-india-norway-ocean-dialogue.txt',
#  'cabinet-approves-mou-between-india-and-oman-on-cooperation-in-the-peaceful-uses-of-outer-space.txt',
#  'cabinet-approves-mou-between-india-and-philippines-on-agriculture-and-related-fields.txt',
#  'cabinet-approves-mou-between-india-and-poland-for-the-promotion-of-civil-aviation-cooperation.txt',
#  'cabinet-approves-mou-between-india-and-romania-in-the-field-of-tourism.txt',
#  'cabinet-approves-mou-between-india-and-russia-on-bilateral-cooperation-in-the-road-transport-and-road-industry.txt',
#  'cabinet-approves-mou-between-india-and-sao-tome-and-principe-for-cooperation-in-the-field-of-traditional-systems-of-medicine-and-homoeopathy.txt',
#  'cabinet-approves-mou-between-india-and-saudi-arabia-on-cooperation-and-mutual-assistance-in-customs-matters.txt',
#  'cabinet-approves-mou-between-india-and-saudi-arabia-on-establishing-a-mechanism-for-investment-infrastructure-in-india.txt',
#  'cabinet-approves-mou-between-india-and-singapore-on-cooperation-in-the-field-of-personnel-management-and-public-administration.txt',
#  'cabinet-approves-mou-between-india-and-singapore-on-cooperation-in-the-field-of-planning.txt',
#  'cabinet-approves-mou-between-india-and-singapore-on-setting-up-of-a-joint-working-group-on-fintech.txt',
#  'cabinet-approves-mou-between-india-and-suriname-for-cooperation-in-the-field-of-electoral-management-and-administration.txt',
#  'cabinet-approves-mou-between-india-and-tajkistan-on-cooperation-on-peaceful-uses-of-space-technology-for-development.txt',
#  'cabinet-approves-mou-between-india-and-tajkistan-on-cooperation-on-youth-matters.txt',
#  'cabinet-approves-mou-between-india-and-the-uae-on-development-cooperation-in-africa.txt',
#  'cabinet-approves-mou-between-india-and-the-usa-concerning-scientific-and-technical-cooperation-in-the-earth-sciences.txt',
#  'cabinet-approves-mou-between-india-and-turkey-on-trade-in-poppy-seeds.txt',
#  'cabinet-approves-mou-between-india-and-uk-on-cooperation-in-the-sphere-of-law-justice-and-establishing-a-joint-consultative-committee.txt',
#  'cabinet-approves-mou-between-india-and-uk-on-technical-cooperation-in-the-field-of-sustainable-urban-development.txt',
#  'cabinet-approves-mou-between-india-and-uzbekistan-for-strengthening-cooperation-in-the-field-of-tourism.txt',
#  'cabinet-approves-mou-between-india-and-uzbekistan-on-cooperation-for-establishment-of-uzbek-indian-free-pharmaceutical-zone-in-the-andijan-region-of-uzbekistan.txt',
#  'cabinet-approves-mou-between-india-and-uzbekistan-on-cooperation-in-the-sphere-of-law-justice.txt',
#  'cabinet-approves-mou-between-india-and-uzbekistan-on-mutual-cooperation-in-combating-illicit-trafficking-in-narcotics-drugs-psychotropic-substances-and-precursors.txt',
#  'cabinet-approves-mou-between-india-and-vietnam-on-joint-issue-of-postage-stamp.txt',
#  'cabinet-approves-mou-between-the-icai-and-bahrain-institute-of-banking-and-finance-bahrain.txt',
#  'cabinet-approves-mou-between-the-icai-and-certified-professional-accountants-afghanistan-cpa-afghanistan.txt',
#  'cabinet-approves-mou-between-the-icai-and-national-board-of-accountants-and-auditors-tanzania.txt',
#  'cabinet-approves-mou-between-the-icai-and-the-institute-of-certified-public-accountants-of-kenya.txt',
#  'cabinet-approves-mou-between-the-icmr-and-inserm-france.txt',
#  'cabinet-approves-mou-on-maritime-issues-between-india-and-denmark.txt',
#  'cabinet-approves-mou-signed-between-india-and-france-in-the-field-of-renewable-energy.txt',
#  'cabinet-approves-mou-with-mauritius-on-consumer-protection-and-legal-metrology.txt',
#  'cabinet-approves-moubetween-india-and-russia-on-joint-activities-under-human-spaceflight-programme.txt',
#  'cabinet-approves-moubetween-india-and-zimbabwe-for-cooperation-in-the-field-of-geology-mining-and-mineral-resources.txt',
#  'cabinet-approves-mutual-recognition-agreement-between-the-icai-and-the-south-african-institute-of-chartered-accountants.txt',
#  'cabinet-approves-national-digital-communications-policy-2018.txt',
#  'cabinet-approves-national-monitoring-framework-on-sustainable-development-goals.txt',
#  'cabinet-approves-patna-metro-rail-project-comprising-two-corridors-danapur-to-mithapur-patna-railway-station-of-new-isbt.txt',
#  'cabinet-approves-polar-satellite-launch-vehicle-mark-iii-continuation-programme-phase-6.txt',
#  'cabinet-approves-policy-framework-for-exploration-and-exploitation-of-unconventional-hydrocarbons.txt',
#  'cabinet-approves-productivity-linked-bonus-for-railway-employees.txt',
#  'cabinet-approves-proposal-for-allotment-of-land-to-pasteur-institute-of-india-for-establishment-of-new-viral-vaccine-manufacturing-unit-at-coonoor-tn.txt',
#  'cabinet-approves-proposal-for-enactment-of-dam-safety-bill-2018.txt',
#  'cabinet-approves-proposal-for-leasing-out-land-at-alipur-delhi-owned-by-dms-to-small-farmers-agribusiness-consortium.txt',
#  'cabinet-approves-proposal-for-withdrawal-of-nalanda-university-amendment-bill-2013-pending-in-rajya-sabha.txt',
#  'cabinet-approves-proposal-to-allot-land-to-chandigarh-housing-board-for-construction-of-apartments-for-3930-allottees-under-self-financing-housing-scheme-for-ut-employees.txt',
#  'cabinet-approves-raising-of-ebr-for-swachh-bharat-mission-gramin-sbmg-amounting-up-to-rs-15000-crore-during-the-financial-year-2018-19.txt',
#  'cabinet-approves-raising-of-four-additional-battalions-of-national-disaster-response-force.txt',
#  'cabinet-approves-re-structuring-of-the-agricultural-scientists-recruitment-board-asrb.txt',
#  'cabinet-approves-redevelopment-of-railway-stations-by-irsdc-as-nodal-agency-through-simplified-procedures-and-longer-lease-tenure.txt',
#  'cabinet-approves-renaming-of-agartala-airport-tripura-as-maharaja-bir-bikram-manikya-kishore-airport-agartala.txt',
#  'cabinet-approves-renewal-of-mou-between-the-icai-saudi-organisation-for-certified-public-accountants.txt',
#  'cabinet-approves-repositioning-of-north-eastern-council.txt',
#  'cabinet-approves-resolution-for-adoption-of-the-recommendations-of-the-railway-convention-committee.txt',
#  'cabinet-approves-restructuring-of-the-indian-bureau-of-mines-ibm.txt',
#  'cabinet-approves-revised-guidelines-on-time-bound-closure-of-sick-loss-making-cpses-and-disposal-of-movable-and-immovable-assets.txt',
#  'cabinet-approves-revised-model-mou-between-india-and-foreign-financial-intelligence-units-fius-for-exchange-of-information.txt',
#  'cabinet-approves-revisedsalaries-gratuity-allowances-and-pension-for-the-judges-of-the-supreme-court-and-the-high-courts.txt',
#  'cabinet-approves-revision-in-the-list-of-scheduled-tribes-of-chhattisgarh.txt',
#  'cabinet-approves-revision-in-the-wage-structure-and-allowances-of-gramin-dak-sevaks-gds-of-the-department-of-posts.txt',
#  'cabinet-approves-revision-of-pay-and-allowances-of-lieutenant-governors-of-union-territories.txt',
#  'cabinet-approves-scheme-for-setting-up-of-indian-institute-of-skills-at-different-locations-across-the-country-in-ppp-modes.txt',
#  'cabinet-approves-second-protocol-amending-the-comprehensive-economic-cooperation-agreement-between-india-and-singapore.txt',
#  'cabinet-approves-setting-up-of-a-central-university-in-andhra-pradesh.txt',
#  'cabinet-approves-setting-up-of-a-new-aiims-in-deoghar-jharkhand.txt',
#  'cabinet-approves-setting-up-of-a-special-purpose-vehicle-to-be-called-government-e-marketplace.txt',
#  'cabinet-approves-setting-up-of-medical-college-at-silvassa-in-the-ut-of-dadra-and-nagar-haveli.txt',
#  'cabinet-approves-setting-up-of-national-nutrition-mission.txt',
#  'cabinet-approves-setting-up-of-new-aiims-in-bilaspur.txt',
#  'cabinet-approves-setting-up-of-the-15th-finance-commission.txt',
#  'cabinet-approves-setting-up-of-the-national-commission-for-homoeopathy-nch-bill-2018.txt',
#  'cabinet-approves-signing-an-agreement-between-india-and-armenia-on-cooperation-and-mutual-assistance-in-customs-matters.txt',
#  'cabinet-approves-signing-and-ratification-of-agreement-between-india-and-brunei-darussalam-for-the-exchange-of-information-and-assistance-in-collection-with-respect-to-taxes.txt',
#  'cabinet-approves-signing-of-agreement-between-india-and-ukraine-for-cooperation-in-agriculture-and-food-industry.txt',
#  'cabinet-approves-signing-of-bilateral-investment-agreement-between-india-taipei-association-in-taipei-and-the-taipei-economic-and-cultural-center-in-india.txt',
#  'cabinet-approves-signing-of-fou-between-india-and-bangladesh-on-cooperation-in-the-hydrocarbon-sector.txt',
#  'cabinet-approves-signing-of-india-russia-agreement-on-cooperation-in-combating-terrorism-and-organized-crime.txt',
#  'cabinet-approves-signing-of-memorandum-of-understanding-amongst-brics-nations-on-the-regional-aviation-partnership.txt',
#  'cabinet-approves-signing-of-mou-between-india-and-argentine-in-tourism.txt',
#  'cabinet-approves-signing-of-mou-between-india-and-australia-for-cooperation-in-the-disability-sector.txt',
#  'cabinet-approves-signing-of-mou-between-india-and-saudi-arabia-in-the-field-of-tourism.txt',
#  'cabinet-approves-signing-of-the-tor-provide-tax-assistance-to-swaziland.txt',
#  'cabinet-approves-special-remission-to-prisoners-on-the-occasion-of-150th-birth-anniversary-of-mahatma-gandhi.txt',
#  'cabinet-approves-strengthening-of-teaching-patient-clinical-care-and-public-health-programme-implementation-shifting-of-more-experienced-doctors-belonging-to-central-government-and-central-governme.txt',
#  'cabinet-approves-submission-of-indias-second-biennial-update-report-bur-to-united-nations-framework-convention-on-climate-change-unfccc.txt',
#  'cabinet-approves-the-agreement-between-india-and-kyrgyz-for-the-avoidance-of-double-taxation-and-the-prevention-of-fiscal-evasion-in-the-taxes-on-income.txt',
#  'cabinet-approves-the-constitution-scheduled-tribes-order-amendment-bill-2018-for-revision-in-list-of-scheduled-tribes-of-arunachal-pradesh.txt',
#  'cabinet-approves-the-establishment-of-the-national-anti-profiteering-authority-under-gst.txt',
#  'cabinet-approves-the-extension-of-mou-between-india-and-netherlands-on-technical-cooperation-in-the-field-of-spatial-planning-water-management-and-mobility-management.txt',
#  'cabinet-approves-the-increase-in-the-carpet-area-of-houses-eligible-for-interest-subsidy-for-the-middle-income-group-under-pmay.txt',
#  'cabinet-approves-the-joint-issue-of-postage-stamp-between-india-and-russia.txt',
#  'cabinet-approves-the-mra-signed-in-2010-and-approves-fresh-mra-between-the-icai-and-the-institute-of-certified-public-accountants-ireland.txt',
#  'cabinet-approves-the-signing-and-ratification-of-mou-for-establishment-of-the-bimstec-grid-interconnection.txt',
#  'cabinet-approves-transfer-of-4-acres-of-defence-land-on-lease-basis-to-kendriya-vidyalaya-sangathan-for-the-construction-of-kendriya-vidyalaya-no-4-at-kandhar-lines-delhi-cantt.txt',
#  'cabinet-approves-transfer-of-7-118-acres-of-defence-land-to-kendriya-vidyalaya-sangathan-for-construction-of-kendriya-vidyalaya-number-2-dhar-road-in-district-udhampur-jk.txt',
#  'cabinet-approves-transfer-of-7-5-acres-of-defence-land-to-kendriya-vidyalaya-sangathan-for-the-construction-of-kendriya-vidvalaya-in-survey-no-408-jalandhar-cantt.txt',
#  'cabinet-approves-transfer-of-central-hospital-at-karma.txt',
#  'cabinet-approves-transfer-of-sashastra-seema-bals-land-measuring-5-99-acres-at-tawang-to-the-state-government-of-arunachal-pradesh.txt',
#  'cabinet-approves-umbrella-schemes-for-relief-and-rehabilitation-of-migrants-and-repatriates.txt',
#  'cabinet-approves-wage-policy-for-the-8th-round-of-wage-negotiations-for-workmen-in-central-public-sector-enterprises.txt',
#  'cabinet-approvesa-cooperation-arrangement-between-india-and-afghanistan-for-cooperation-in-the-field-of-food-safety-and-related-areas.txt',
#  'cabinet-approvesamendment-to-the-framework-on-currency-swap-arrangement-for-saarc.txt',
#  'cabinet-approvesmou-between-india-and-iran-on-the-establishment-of-an-expert-group-on-trade-remedy-measures.txt',
#  'cabinet-condoles-the-demise-of-dr-m-karunanidhi-former-chief-minister-of-tamil-nadu.txt',
#  'cabinet-gives-approval-to-the-approach-to-be-adopted-by-india-at-the-eleventh-ministerial-conference-of-the-wto.txt',
#  'defence-minister-of-japan-calls-on-the-pm.txt',
#  'delegation-from-film-and-entertainment-industry-meets-pm.txt',
#  'delegation-from-pacific-pension-and-investment-institute-calls-on-pm.txt',
#  'delegation-of-obc-mps-and-leaders-calls-on-pm.txt',
#  'delegation-of-sgpc-with-minister-of-food-processing-industries-calls-on-pm.txt',
#  'dg-itbp-presents-a-cheque-of-rs-8-5-crore-towards-prime-ministers-national-relief-fund.txt',
#  'dg-wto-calls-on-pm.txt',
#  'dr-h-wiranto-indonesias-coordinating-minister-for-political-legal-and-security-affairs-calls-on-prime-minister.txt',
#  'excerpts-from-pms-address-at-the-programme-marking-the-start-of-the-surat-marathon.txt',
#  'excerpts-from-pms-interaction-with-participants-across-the-globe-in-bharat-ki-baat-sabke-saath-programme-at-london.txt',
#  'first-ever-philip-kotler-presidential-award-presented-to-pm.txt',
#  'foreign-minister-of-bangladesh-calls-on-pm.txt',
#  'foreign-minister-of-japan-calls-on-pm-2.txt',
#  'former-pm-of-nepal-shri-pushpa-kamal-dahal-prachanda-calls-on-pm.txt',
#  'french-minister-for-europe-and-foreign-affairs-calls-on-pm-2.txt',
#  'french-minister-for-europe-and-foreign-affairs-calls-on-pm.txt',
#  'french-minister-for-the-armed-forces-calls-on-the-prime-minister.txt',
#  'global-trade-show-the-flagship-event-in-the-run-up-to-vibrant-gujarat-summit-inaugurated-by-pm-in-gandhinagar.txt',
#  'highlights-of-pms-reply-to-the-motion-of-thanks-on-the-presidents-address-in-the-lok-sabha.txt',
#  'honouring-the-legacy-of-mahatma-gandhi.txt',
#  'inculcating-national-pride-through-memorials.txt',
#  'india-is-changing-because-indians-have-decided-to-change-pm.txt',
#  'india-russia-joint-statement-during-the-visit-of-the-president-of-russia-to-india.txt',
#  'india-uganda-joint-statement-during-state-visit-of-prime-minister-to-uganda.txt',
#  'indian-foreign-service-officer-trainees-call-on-the-pm.txt',
#  'indias-first-semi-high-speed-train-vande-bharat-express-to-be-flagged-off-by-pm-tomorrow.txt',
#  'ips-officer-trainees-of-2016-batch-call-on-pm.txt',
#  'ips-probationers-of-2017-batch-call-on-pm.txt',
#  'joint-press-statement-from-the-summit-between-india-and-the-nordic-countries.txt',
#  'joint-statement-on-the-occasion-of-state-visit-of-the-president-of-the-republic-of-maldives-to-india.txt',
#  'justice-ranjan-gogoi-appointed-as-next-chief-justice-of-india.txt',
#  'leader-of-opposition-of-canada-andrew-scheer-calls-on-pm.txt',
#  'lic-to-acquire-controlling-stake-of-idbi-bank.txt',
#  'list-of-agreements-mous-exchanged-between-india-and-russia-during-the-visit-of-the-president-of-russia.txt',
#  'list-of-mous-agreements-signed-during-state-visit-of-crown-prince-of-saudi-arabia-to-india.txt',
#  'list-of-mous-signed-between-india-and-seychelles-during-the-state-visit-of-president-of-seychelles-to-india.txt',
#  'list-of-mousagreements-signed-during-state-visit-of-prime-minister-to-myanmar.txt',
#  'list-of-mousagreements-signed-during-the-state-visit-of-prime-minister-of-the-kingdom-of-cambodia-to-india.txt',
#  'list-of-mousagreements-signed-during-the-visit-of-prime-minister-of-israel-to-india.txt',
#  'list-of-mousagreements-signed-during-the-visit-of-prime-minister-of-italy-to-india.txt',
#  'members-of-oman-india-joint-business-council-meet-pm.txt',
#  'members-of-the-parliament-of-sri-lanka-calls-on-pm.txt',
#  'mr-greg-abbott-governor-of-texas-calls-on-pm.txt',
#  'mr-john-chambers-chairman-of-us-india-strategic-partnership-forum-calls-on-the-pm.txt',
#  'mr-matt-bevin-governor-of-kentucky-calls-on-the-pm.txt',
#  'newly-elected-sarpanches-from-jk-call-on-pm.txt',
#  'on-earthday-pm-reaffirms-commitment-towards-creating-a-better-planet.txt',
#  'pareeksha-pe-charcha-pms-interactive-session-with-students.txt',
#  'pm-addresses-book-release-event-to-mark-one-year-in-office-of-vice-president-venkaiah-naidu.txt',
#  'pm-addresses-civil-servants-on-the-occasion-of-civil-services-day.txt',
#  'pm-addresses-concluding-session-of-governors-conference.txt',
#  'pm-addresses-concluding-session-of-mahatma-gandhi-international-sanitation-convention.txt',
#  'pm-addresses-credai-youthcon-2019.txt',
#  'pm-addresses-event-to-mark-launch-of-the-centre-for-the-fourth-industrial-revolution.txt',
#  'pm-addresses-ex-servicemen-attends-dedication-ceremony-of-national-war-memorial.txt',
#  'pm-addresses-inaugural-session-of-end-tb-summit.txt',
#  'pm-addresses-inaugural-session-of-pio-parliamentarian-conference.txt',
#  'pm-addresses-indian-community-in-philippines.txt',
#  'pm-addresses-indian-community-in-uganda.txt',
#  'pm-addresses-indian-community-in-yangon.txt',
#  'pm-addresses-international-convention-of-saurashtra-patel-cultural-samaj-through-video-conference.txt',
#  'pm-addresses-jan-abhar-rally-in-dharamshala-to-mark-one-year-of-himachal-pradesh-government.txt',
#  'pm-addresses-krishi-unnati-mela.txt',
#  'pm-addresses-make-in-india-seminar-in-tokyo-japan.txt',
#  'pm-addresses-national-convention-of-swachhagrahis-launches-development-projects-in-motihari.txt',
#  'pm-addresses-ncc-rally.txt',
#  'pm-addresses-new-india-conclave.txt',
#  'pm-addresses-public-meeting-in-chotila-lays-foundation-stone-for-greenfield-airport-for-rajkot.txt',
#  'pm-addresses-public-meeting-on-the-occasion-of-commencement-of-work-for-the-rajasthan-refinery-in-barmer-rajasthan.txt',
#  'pm-addresses-republic-tv-summit.txt',
#  'pm-addresses-silver-jubilee-celebrations-of-the-shree-kutchi-leva-patel-samaj-in-nairobi-kenya-via-video-conferencing.txt',
#  'pm-addresses-swachh-kumbh-swachh-aabhaar-programme-in-prayagraj.txt',
#  'pm-addresses-the-4th-international-yoga-day.txt',
#  'pm-addresses-the-jagran-forum-on-the-occasion-of-75th-anniversary-celebration-of-dainik-jagran.txt',
#  'pm-addresses-the-ncc-rally.txt',
#  'pm-addresses-valedictory-ceremony-at-dgpigp-conference-at-tekanpur.txt',
#  'pm-addresses-valedictory-session-of-national-law-day-2017.txt',
#  'pm-addresses-young-ceos-at-the-champions-of-change-initiative-organised-by-niti-aayog.txt',
#  'pm-and-president-putin-exchange-greetings.txt',
#  'pm-and-u-s-president-donald-j-trump-exchange-greetings-in-the-new-year.txt',
#  'pm-announces-ex-gratia-for-the-next-of-kin-of-those-who-lost-their-lives-due-to-collapse-of-an-under-construction-flyover-in-varanasi-from-pmnrf.txt',
#  'pm-announces-sardar-patel-award-for-national-integration.txt',
#  'pm-arrives-at-tekanpur-attends-conference-of-dgsp-and-igsp.txt',
#  'pm-at-prayagraj-inaugurates-new-airport-complex-integrated-command-and-control-centre-for-kumbh-mela-launches-development-projects.txt',
#  'pm-attends-ashara-mubaraka-commemoration-of-martyrdom-of-imam-husain-sa-in-indore-addresses-gathering.txt',
#  'pm-attends-convocation-of-gujarat-forensic-sciences-university.txt',
#  'pm-attends-dashamah-soundarya-lahari-parayanotsava-mahasamarpane-at-bengaluru.txt',
#  'pm-attends-event-to-mark-the-presentation-of-gandhi-peace-prize.txt',
#  'pm-attends-ground-breaking-ceremony-of-navi-mumbai-international-airport-dedicates-fourth-container-terminal-at-jnpt.txt',
#  'pm-attends-groundbreaking-ceremony-of-various-projects-in-uttar-pradesh.txt',
#  'pm-attends-niti-aayogs-interaction-with-economists-and-experts-on-economic-policy-the-road-ahead.txt',
#  'pm-bangladesh-pm-sheikh-hasina-jointly-unveil-e-plaques-for-ground-breaking-of-two-projects.txt',
#  'pm-bows-to-bhagwan-birsa-munda-on-his-jayanti.txt',
#  'pm-bows-to-dr-babasaheb-ambedkar-on-his-mahaparinirvan-diwas.txt',
#  'pm-bows-to-swami-vivekananda-on-his-jayanti.txt',
#  'pm-celebrates-diwali-with-jawans-in-harsil-uttarakhand.txt',
#  'pm-celebrates-diwali-with-jawans-of-indian-army-and-bsf-in-gurez-valley.txt',
#  'pm-concludes-his-visit-to-gujarat.txt',
#  'pm-condemns-attack-on-crpf-personnel-in-pulwama-kashmir.txt',
#  'pm-condemns-the-terror-attacks-in-afghanistan.txt',
#  'pm-condoles-demise-of-captain-jai-narain-prasad-nishad.txt',
#  'pm-condoles-demise-of-former-prime-minister-shri-atal-bihari-vajpayee.txt',
#  'pm-condoles-demise-of-kader-khan.txt',
#  'pm-condoles-demise-of-shri-ambareesh.txt',
#  'pm-condoles-demise-of-shri-c-k-jaffer-sharief.txt',
#  'pm-condoles-demise-of-shri-madan-lal-khurana.txt',
#  'pm-condoles-loss-of-lives-due-to-a-bus-accident-in-maharashtra.txt',
#  'pm-condoles-loss-of-lives-due-to-cyclone-in-tamil-nadu.txt',
#  'pm-condoles-loss-of-lives-due-to-derailment-of-seemanchal-express.txt',
#  'pm-condoles-loss-of-lives-due-to-train-accident-in-amritsar.txt',
#  'pm-condoles-loss-of-lives-due-to-tsunami-in-indonesia.txt',
#  'pm-condoles-loss-of-lives-in-the-earth-quake-in-iran-and-iraq.txt',
#  'pm-condoles-the-demise-of-ls-mp-and-former-union-minister-shri-sultan-ahmed.txt',
#  'pm-condoles-the-passing-away-of-kalaignar-karunanidhi.txt',
#  'pm-condoles-the-passing-away-of-kuldip-nayar.txt',
#  'pm-condoles-the-passing-away-of-professor-stephen-hawking.txt',
#  'pm-condoles-the-passing-away-of-renowned-sufi-singer-shri-pyarelal-wadali.txt',
#  'pm-condoles-the-passing-away-of-shri-balramji-dass-tandon-the-governor-of-chhattisgarh.txt',
#  'pm-condoles-the-passing-away-of-shri-mohammad-asrarul-haque.txt',
#  'pm-condoles-the-passing-away-of-shri-priya-ranjan-dasmunsi.txt',
#  'pm-condoles-the-passing-away-of-versatile-actor-shashi-kapoor.txt',
#  'pm-congratulates-aanchal-thakur-on-winning-indias-first-international-medal-in-skiing.txt',
#  'pm-congratulates-arpinder-singh-on-winning-gold-in-mens-triple-jump-event.txt',
#  'pm-congratulates-bharat-ratna-awardees.txt',
#  'pm-congratulates-chennai-on-citys-inclusion-in-unesco-creative-cities-network.txt',
#  'pm-congratulates-dipa-karmakar-on-winning-gold-in-vault-event-at-fig-world-challenge-cup.txt',
#  'pm-congratulates-h-e-tun-dr-mahathir-mohamad-prime-minister-of-malaysia.txt',
#  'pm-congratulates-hima-das-on-winning-gold-in-400m-of-world-u20-championships.txt',
#  'pm-congratulates-his-japanese-counterpart-shinzo-abe-on-re-election.txt',
#  'pm-congratulates-indias-contingent-at-the-2018-commonwealth-games.txt',
#  'pm-congratulates-isro-for-successful-launch-of-pslv.txt',
#  'pm-congratulates-isro-scientists-on-successful-launch-of-gslv-mk-iii-d2-carrying-gsat-29-satellite.txt',
#  'pm-congratulates-isro-scientists-on-the-successful-launch-of-irnss-1i.txt',
#  'pm-congratulates-isro-team-for-the-successful-launch-of-its-100th-satellite.txt',
#  'pm-congratulates-john-key-on-re-election-as-pm%E2%80%8B-of-new-zealand.txt',
#  'pm-congratulates-justice-dalveer-bhandari-on-being-re-elected-to-the-international-court-of-justice.txt',
#  'pm-congratulates-kidambi-srikanth-on-his-victory-at-denmark-open-super-series-premier-2017.txt',
#  'pm-congratulates-mary-kom-on-her-gold-at-asian-confederation-womens-boxing-championships.txt',
#  'pm-congratulates-mary-kom-on-winning-gold-in-womens-world-boxing-championships.txt',
#  'pm-congratulates-medal-winners-in-commonwealth-games.txt',
#  'pm-congratulates-sanjita-chanu-on-winning-the-gold-medal-in-the-womens-53-kg-weightlifting-event.txt',
#  'pm-congratulates-sathish-kumar-sivalingam-on-winning-the-gold-medal-in-the-mens-77-kg-weightlifting-event.txt',
#  'pm-congratulates-saurabh-chaudhary-on-winning-gold-in-mens-10m-air-pistol-event.txt',
#  'pm-congratulates-tejaswini-sawant-for-the-gold-in-the-womens-50m-rifle-3-positions-event.txt',
#  'pm-congratulates-the-president-of-india-on-completing-one-year-in-office.txt',
#  'pm-congratulates-vikas-thakur-on-winning-the-bronze-medal-in-the-mens-94-kg-weightlifting-event.txt',
#  'pm-congratulates-vinesh-phogat-on-winning-gold-in-50kg-wrestling-event.txt',
#  'pm-congratulates-weightlifter-deepak-lather-on-clinching-a-bronze-in-the-mens-69-kg-category-at-commonwealth-games.txt',
#  'pm-conveys-diwali-greetings-to-the-crew-of-insv-tarini.txt',
#  'pm-conveys-his-greetings-on-world-consumer-rights-day.txt',
#  'pm-dedicates-all-india-institute-of-ayurveda-to-the-nation.txt',
#  'pm-dedicates-bogibeel-bridge-to-the-nation-flags-off-first-passenger-train.txt',
#  'pm-dedicates-dr-ambedkar-international-centre-to-the-nation.txt',
#  'pm-dedicates-iit-gandhinagar-campus-to-the-nation.txt',
#  'pm-dedicates-ins-kalvari-to-the-nation.txt',
#  'pm-dedicates-lays-foundation-stone-for-key-projects-in-aiims.txt',
#  'pm-dedicates-national-police-memorial-to-the-nation-announces-an-award-in-the-name-of-subash-chandra-bose.txt',
#  'pm-dedicates-national-salt-satyagraha-memorial-in-dandi-gujarat-to-the-nation.txt',
#  'pm-dedicates-statue-of-unity-to-the-nation.txt',
#  'pm-dedicates-to-the-nation-integrated-refinery-expansion-complex-and-mounded-storage-vessel-at-lpg-bottling-plant-in-kochi.txt',
#  'pm-delivers-inaugural-address-at-106th-session-of-indian-science-congress.txt',
#  'pm-exhorts-people-to-pledge-for-leading-healthier-lifestyle-to-overcome-diabetes-on-the-world-diabetes-day.txt',
#  'pm-expresses-condolences-on-the-passing-away-of-george-fernandes.txt',
#  'pm-expresses-condolences-on-the-passing-away-of-shri-ladu-kishore-swain.txt',
#  'pm-expresses-condolences-on-the-passing-away-of-union-minister-shri-ananth-kumar.txt',
#  'pm-expresses-grief-on-loss-of-lives-due-to-accident-in-bihar.txt',
#  'pm-expresses-grief-on-shocking-demise-of-actor-sridevi.txt',
#  'pm-expresses-grief-over-accident-at-raebareli-ntpc-plant.txt',
#  'pm-expresses-grief-over-demise-of-former-meghalaya-governor-mr-m-m-jacob.txt',
#  'pm-expresses-pain-over-the-loss-of-lives-due-to-fire-in-mumbai.txt',
#  'pm-expresses-sadness-over-the-loss-of-lives-due-to-collapse-ofan-under-construction-flyover-in-varanasi.txt',
#  'pm-expresses-solidarity-with-the-people-of-kerala-on-onam.txt',
#  'pm-extends-greetings-on-navy-day.txt',
#  'pm-extends-greetings-on-world-radio-day-2.txt',
#  'pm-extends-his-condolences-on-loss-of-lives-in-an-accident-in-gujarat.txt',
#  'pm-extends-his-greetings-on-army-day.txt',
#  'pm-extends-his-greetings-on-navroz.txt',
#  'pm-extends-his-greetings-on-odisha-formation-day-utkal-divas.txt',
#  'pm-felicitates-crew-of-ins-arihant-on-completion-of-nuclear-triad.txt',
#  'pm-felicitates-medal-winners-of-2018-summer-youth-olympics.txt',
#  'pm-flags-off-train-between-varanasi-and-patna-launches-various-development-projects-addresses-public-meeting-in-varanasi.txt',
#  'pm-gifts-cows-to-villagers-at-rweru-model-village-as-part-of-the-rwandan-governments-girinka-programme.txt',
#  'pm-greets-bsf-personnel-on-their-raising-day-2.txt',
#  'pm-greets-cisf-personnel-on-the-raising-day-of-cisf.txt',
#  'pm-greets-gujaratis-across-the-world-on-the-beginning-of-new-year-2.txt',
#  'pm-greets-itbp-on-its-raising-day.txt',
#  'pm-greets-media-persons-on-national-press-day.txt',
#  'pm-greets-nation-on-christmas.txt',
#  'pm-greets-people-across-nation-on-various-festivals.txt',
#  'pm-greets-people-of-bihar-on-bihar-diwas-2.txt',
#  'pm-greets-people-of-gujarat-on-gujarat-diwas.txt',
#  'pm-greets-people-of-himachal-pradesh-on-their-statehood-day.txt',
#  'pm-greets-people-of-maharashtra-on-their-statehood-day.txt',
#  'pm-greets-people-of-meghalaya-on-their-statehood-day-2.txt',
#  'pm-greets-people-of-nagaland-on-statehood-day-2.txt',
#  'pm-greets-people-of-nagaland-on-statehood-day.txt',
#  'pm-greets-people-of-tripura-on-their-statehood-day-2.txt',
#  'pm-greets-people-on-ambedkar-jayanti.txt',
#  'pm-greets-people-on-buddha-purnima-2.txt',
#  'pm-greets-people-on-cheti-chand.txt',
#  'pm-greets-people-on-guru-purnima-3.txt',
#  'pm-greets-people-on-national-voters-day.txt',
#  'pm-greets-people-on-navreh.txt',
#  'pm-greets-people-on-the-beginning-of-holy-month-of-ramzan.txt',
#  'pm-greets-people-on-world-environment-day.txt',
#  'pm-greets-science-lovers-on-national-science-day.txt',
#  'pm-greets-teaching-community-on-teachers-day-pays-tributes-to-former-president-dr-sarvepalli-radhakrishnan-on-his-jayanti.txt',
#  'pm-greets-the-people-of-jharkhand-on-their-statehood-day.txt',
#  'pm-greets-the-people-on-the-occasion-of-various-festivals-across-india-3.txt',
#  'pm-greets-un-on-united-nations-day.txt',
#  'pm-hails-indias-historic-jump-in-ease-of-doing-business-rankings.txt',
#  'pm-hands-over-chaadar-to-be-offered-at-dargah-of-khwaja-moinuddin-chishti-4.txt',
#  'pm-in-chhattisgarh-addresses-kisan-sammelan-at-janjgir-champa-lays-foundation-stone-for-important-infrastructure-projects.txt',
#  'pm-in-ghazipur-releases-commemorative-stamp-on-maharaja-suheldev-lays-foundation-stone-of-medical-college-in-ghazipur.txt',
#  'pm-in-jammu-2.txt',
#  'pm-in-jammu-3.txt',
#  'pm-in-leh.txt',
#  'pm-in-mirzapur-dedicates-bansagar-canal-project-to-the-nation.txt',
#  'pm-in-srinagar.txt',
#  'pm-in-surat-today.txt',
#  'pm-in-varanasi-5.txt',
#  'pm-in-varanasi-dedicates-multimodal-terminal-to-the-nation-inaugurates-major-road-projects.txt',
#  'pm-inaugurates-eastern-peripheral-expressway-and-phase-i-of-delhi-meerut-expressway.txt',
#  'pm-inaugurates-key-development-projects-in-varanasi.txt',
#  'pm-inaugurates-kundli-manesar-section-of-western-peripheral-expressway-andballabgarh-mujesar-metro-link.txt',
#  'pm-inaugurates-launches-development-works-in-baripada-odisha.txt',
#  'pm-inaugurates-lng-terminal-and-pipeline-projects-at-anjar.txt',
#  'pm-inaugurates-modern-food-processing-facilities-in-anand.txt',
#  'pm-inaugurates-new-asi-headquarters-in-new-delhi.txt',
#  'pm-inaugurates-new-metro-link-between-noida-and-delhi.txt',
#  'pm-inaugurates-newly-constructed-transit-accommodation-for-mps-at-western-court-annexe.txt',
#  'pm-inaugurates-pakyong-airport-as-air-connectivity-reaches-sikkim.txt',
#  'pm-inaugurates-parakram-parv-pays-homage-to-martyrs-at-konark-war-memorial.txt',
#  'pm-inaugurates-petrotech-2019-says-energy-is-a-key-driver-of-socio-economic-growth.txt',
#  'pm-inaugurates-phase-1-of-ro-ro-ferry-service-between-ghogha-and-dahej-travels-in-maiden-voyage-of-the-service.txt',
#  'pm-inaugurates-state-of-the-art-hospital-in-surat-says-ayushman-bharat-will-improve-healthcare-services-and-facilities.txt',
#  'pm-inaugurates-the-ahmedabad-shopping-festival-2019.txt',
#  'pm-inaugurates-various-projects-in-junagadh-district.txt',
#  'pm-interacts-with-beneficiaries-of-pradhan-mantri-bhartiya-janaushadhi-pariyojana.txt',
#  'pm-interacts-with-beneficiaries-of-various-digital-india-initiatives-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-beneficiaries-of-various-health-care-schemes-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-beneficiaries-of-various-social-security-schemes-across-the-country-via-video-bridge.txt',
#  'pm-interacts-with-business-leaders-in-mumbai.txt',
#  'pm-interacts-with-farmers-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-indian-community-in-tokyo-japan.txt',
#  'pm-interacts-with-it-and-electronic-manufacturing-professionals-on-the-occasion-of-the-launch-of-main-nahin-hum-portal-and-app.txt',
#  'pm-interacts-with-members-of-self-help-groups-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-mission-gange-delegation.txt',
#  'pm-interacts-with-mudrayojana-beneficiaries-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-pradhan-mantri-awas-yojana-beneficiaries-across-the-country-through-video-bridge.txt',
#  'pm-interacts-with-recipients-of-nari-shakti-puraskar-2.txt',
#  'pm-interacts-with-recipients-of-nari-shakti-puraskar.txt',
#  'pm-interacts-with-schoolchildren-evaluates-development-works-in-varanasi.txt',
#  'pm-interacts-with-students-teachers-and-parents-at-pariksha-pe-charcha-2-0.txt',
#  'pm-interacts-with-sugarcane-farmers.txt',
#  'pm-interacts-with-table-tennis-medal-winners-of-commonwealth-games-2018.txt',
#  'pm-interacts-with-the-awardees-of-national-teachers-awards.txt',
#  'pm-interacts-with-the-beneficiaries-of-ayushman-bharat-at-ranchi.txt',
#  'pm-interacts-with-the-members-of-his-science-technology-and-innovation-advisory-council-pm-stiac.txt',
#  'pm-interacts-with-the-newly-elected-sarpanches-lauds-jk-citizens-for-their-commitment-to-democracy-and-development.txt',
#  'pm-interacts-with-ujjwala-beneficiaries-across-the-country.txt',
#  'pm-interacts-with-young-innovators-and-start-up-entrepreneurs-across-the-country-through-video-bridge.txt',
#  'pm-israeli-pm-netanyahu-visit-centre-of-excellence-for-vegetables-at-vadrad.txt',
#  'pm-issues-statement-before-his-departure-to-china.txt',
#  'pm-korean-president-inaugurate-mobile-manufacturing-facility-in-noida.txt',
#  'pm-lauds-the-passage-of-one-hundred-and-twenty-fourth-constitution-amendment-bill-2019-in-the-rajya-sabha.txt',
#  'pm-launches-ayushman-bharat-pmjay-at-ranchi.txt',
#  'pm-launches-development-initiatives-in-vadodara.txt',
#  'pm-launches-development-projects-in-manipur-addresses-public-meeting.txt',
#  'pm-launches-development-projects-in-rae-bareli.txt',
#  'pm-launches-ease-of-doing-business-grand-challenge-addresses-cross-section-of-industry-representatives.txt',
#  'pm-launches-gangajal-project-to-provide-better-and-more-assured-water-supply-in-agra.txt',
#  'pm-launches-historic-support-and-outreach-initiative-for-msme-sector.txt',
#  'pm-launches-india-post-payments-bank-a-major-initiative-towards-financial-inclusion.txt',
#  'pm-launches-pradhan-mantri-shram-yogi-maan-dhan-pm-sym-yojana.txt',
#  'pm-launches-railway-projects-in-mysuru-inaugurates-development-works-at-shravanabelagola.txt',
#  'pm-launches-rashtriya-gramin-swaraj-abhiyan-unveils-roadmap-for-overall-development-of-tribals.txt',
#  'pm-launches-several-development-projects-in-ahmedabad-gujarat.txt',
#  'pm-launches-swachhata-hi-seva-interacts-with-a-cross-section-of-people-from-across-the-country-via-video-conference.txt',
#  'pm-lays-foundation-stone-for-aiims-medical-college-and-hospital-at-madurai.txt',
#  'pm-lays-foundation-stone-for-india-international-convention-and-expo-centre-dwarka.txt',
#  'pm-lays-foundation-stone-for-poorvanchal-expressway-in-azamgarh.txt',
#  'pm-lays-foundation-stone-for-urban-infrastructure-projects-witnesses-experience-sharing-by-beneficiaries-of-welfare-schemes-addresses-public-meeting-in-jaipur.txt',
# ...
#  'pm-reviews-steps-taken-to-reduce-under-nutrition.txt',
#  'pm-salutes-air-warriors-and-their-families-on-air-force-day.txt',
#  'pm-salutes-brave-crpf-personnel-who-were-martyred-in-attack-in-sukma.txt',
#  'pm-salutes-nari-shakti-on-international-womens-day-2.txt',
#  'pm-salutes-the-brave-indian-soldiers-who-laid-down-their-lives-to-liberate-haifa-in-1918-2.txt',
#  'pm-salutes-the-soldiers-who-fought-1971-war-on-the-occasion-of-vijay-diwas.txt',
#  'pm-salutes-the-teaching-community-on-teachers-day-pays-tributes-to-former-president-dr-sarvepalli-radhakrishnan-on-his-birth-anniversary.txt',
#  'pm-serves-3-billionth-meal-to-underprivileged-children-in-vrindavan.txt',
#  'pm-shares-his-fitness-video-nominates-ips-officers-for-fitness-challenge.txt',
#  'pm-shares-his-photos-of-northeast-visit.txt',
#  'pm-speaks-to-kerala-cm-regarding-flood-situation-in-the-state.txt',
#  'pm-to-address-conference-on-transformation-of-aspirational-districts.txt',
#  'pm-to-address-cpse-conclave-at-vigyan-bhawan-tomorrow.txt',
#  'pm-to-address-swachhagrahis-in-champaran-tomorrow.txt',
#  'pm-to-address-the-inaugural-session-of-advantage-assam-global-investors-summit-2018.txt',
#  'pm-to-address-two-video-conferences-on-31st-december-and-1st-january.txt',
#  'pm-to-attend-annual-dgp-conference-at-bsf-academy-in-tekanpur.txt',
#  'pm-to-attend-ashara-mubaraka-commemoration-of-martyrdom-of-imam-husain-sa.txt',
#  'pm-to-attend-commencement-of-work-function-for-rajasthan-refinery-in-barmer-rajasthan.txt',
#  'pm-to-attend-event-to-mark-world-biofuel-day-2018.txt',
#  'pm-to-attend-nhrc-silver-jubilee-foundation-day-function-on-12-october.txt',
#  'pm-to-attend-the-gita-aradhana-mahotsav-at-iskcon-new-delhi-tomorrow.txt',
#  'pm-to-confer-awards-for-excellence-in-public-administration-and-address-civil-servants-tomorrow.txt',
#  'pm-to-dedicate-and-lay-foundation-stone-for-key-projects-in-aiims.txt',
#  'pm-to-dedicate-naval-submarine-ins-kalvari-to-the-nation-tomorrow.txt',
#  'pm-to-dedicate-the-national-war-memorial-to-the-nation-tomorrow.txt',
#  'pm-to-hold-samvad-with-beneficiaries-of-pradhan-mantri-bhartiya-janaushadhi-pariyojna-and-affordable-cardiac-stents-and-knee-implants-on-june-7.txt',
#  'pm-to-inaugurate-15th-pravasi-bharatiya-diwas-convention-in-varanasi-on-22-january-2019.txt',
#  'pm-to-inaugurate-dr-ambedkar-national-memorial-at-alipur-road-in-delhi-tomorrow.txt',
#  'pm-to-inaugurate-new-asi-headquarters-in-new-delhi.txt',
#  'pm-to-inaugurate-petrotech-2019-on-february-11-2019.txt',
#  'pm-to-inaugurate-the-delhi-end-tb-summit-tomorrow.txt',
#  'pm-to-inaugurate-the-dr-ambedkar-international-centre-tomorrow.txt',
#  'pm-to-inaugurate-the-subhash-chandra-bose-museum-at-red-fort.txt',
#  'pm-to-inaugurate-third-annual-meeting-of-aiib-in-mumbai-tomorrow-interact-with-business-leaders.txt',
#  'pm-to-inaugurate-world-sustainable-development-summit-2018-tomorrow.txt',
#  'pm-to-interact-directly-with-beneficiaries-of-national-rural-livelihoods-mission-across-the-country-tomorrow.txt',
#  'pm-to-interact-directly-with-farmers-across-the-country-tomorrow.txt',
#  'pm-to-interact-with-lakhs-of-asha-anm-and-anganwadi-workers-on-11th-september.txt',
#  'pm-to-interact-with-mudra-beneficiaries-tomorrow.txt',
#  'pm-to-interact-with-sugarcane-farmers.txt',
#  'pm-to-interact-with-young-innovators-and-start-up-entrepreneurs-tomorrow.txt',
#  'pm-to-launch-india-post-payments-bank-on-saturday-1st-september.txt',
#  'pm-to-launch-swachh-shakti-2019-from-kurukshetra-tomorrow.txt',
#  'pm-to-launch-swachhata-hi-seva-movement-on-september-15th-2018.txt',
#  'pm-to-lead-4th-international-yoga-day-celebrations-in-dehradun.txt',
#  'pm-to-receive-french-president-emmanuel-macron-in-varanasi-tomorrow.txt',
#  'pm-to-receive-israel-pm-netanyahu-in-gujarat-tomorrow.txt',
#  'pm-to-release-a-commemorative-coin-to-mark-the-birth-anniversary-of-guru-gobind-singh-ji.txt',
#  'pm-to-visit-2-states-2-union-territories-over-the-next-two-days.txt',
#  'pm-to-visit-agra-tomorrow-and-launch-several-projects-worth-rs-2980-crores.txt',
#  'pm-to-visit-bihar-tomorrow.txt',
#  'pm-to-visit-chhattisgarh-on-14th-june-2018.txt',
#  'pm-to-visit-cyclone-ockhi-affected-areas-of-lakshadweep-tamil-nadu-and-kerala-tomorrow.txt',
#  'pm-to-visit-dadra-and-nagar-haveli-tomorrow.txt',
#  'pm-to-visit-durgapur-west-bengal-on-2-february-2019.txt',
#  'pm-to-visit-eastern-up-on-july-14th-and-15th-2018.txt',
#  'pm-to-visit-gujarat-on-23rd-august.txt',
#  'pm-to-visit-gujarat-on-september-30-2018.txt',
#  'pm-to-visit-gujarat-tomorrow-for-vibrant-gujarat-summit-2019.txt',
#  'pm-to-visit-guwahati-itanagar-and-agartala-tomorrow.txt',
#  'pm-to-visit-haryana-on-october-9.txt',
#  'pm-to-visit-hazira-in-surat-tomorrow.txt',
#  'pm-to-visit-himachal-pradesh-tomorrow.txt',
#  'pm-to-visit-jalpaiguri-west-bengal-tomorrow.txt',
#  'pm-to-visit-jammu-and-kashmir-on-may-19-2018.txt',
#  'pm-to-visit-jammu-srinagar-and-leh-on-3-feb-2019.txt',
#  'pm-to-visit-jhansi-in-uttar-pradesh-tomorrow.txt',
#  'pm-to-visit-jharkhand-and-odisha-on-january-5-2019.txt',
#  'pm-to-visit-jhunjhunu-in-rajasthan-on-march-8.txt',
#  'pm-to-visit-kalaburagi-in-karnataka-and-kancheepuram-in-tamil-nadu-on-6th-march-2019.txt',
#  'pm-to-visit-karnataka-tomorrow.txt',
#  'pm-to-visit-kerala-tomorrow-on-january-15-2019.txt',
#  'pm-to-visit-kochi-kerala-on-27-january-2019.txt',
#  'pm-to-visit-kumbh-at-prayagraj-tomorrow.txt',
#  'pm-to-visit-lucknow-on-28th-and-29th-july.txt',
#  'pm-to-visit-madhya-pradesh-on-23rd-june-2018.txt',
#  'pm-to-visit-madurai-tamilnadu-on-27-january2019.txt',
#  'pm-to-visit-maharashtra-on-december-18-2018.txt',
#  'pm-to-visit-maharashtra-tomorrow.txt',
#  'pm-to-visit-manipur-on-16-march-2018.txt',
#  'pm-to-visit-mizoram-and-meghalaya-tomorrow-will-inaugurate-various-development-projects.txt',
#  'pm-to-visit-mumbai-on-11th-august-2018.txt',
#  'pm-to-visit-punjab-on-january-3-2019.txt',
#  'pm-to-visit-rajasthan-on-july-7-2018.txt',
#  'pm-to-visit-santkabir-nagar-on-june-28-2018.txt',
#  'pm-to-visit-shirdi-maharashtra-on-october-19.txt',
#  'pm-to-visit-surat-and-dandi-gujarat-on-30-january-2019.txt',
#  'pm-to-visit-uttar-pradesh-on-december-16-2018.txt',
#  'pm-to-visit-uttar-pradesh-tomorrow.txt',
#  'pm-to-visit-varanasi-on-september-17-and-18-2018.txt',
#  'pm-to-visit-varanasi-tomorrow-2.txt',
#  'pm-to-visit-west-bengal-and-jharkhand-on-may-25.txt',
#  'pm-unveils-important-projects-relating-to-housing-and-urban-development-in-maharashtra.txt',
#  'pm-visits-agartala.txt',
#  'pm-visits-ananda-temple-bagan.txt',
#  'pm-visits-chhattisgarh-inaugurates-integrated-command-and-control-centre-at-naya-raipur.txt',
#  'pm-visits-former-pm-shri-atal-bihari-vajpayee-at-aiims.txt',
#  'pm-visits-guntur-dedicates-1-33-mmt-visakhapatnam-spr-facility-to-the-nation.txt',
#  'pm-visits-guwahati-lays-foundation-stone-of-north-east-gas-grid-unveils-various-development-projects.txt',
#  'pm-visits-haryana-unveils-statue-of-sir-chhotu-ram-lays-foundation-stone-of-rail-coach-refurbishing-karkhana.txt',
#  'pm-visits-irri-mahaveer-philippine-foundation.txt',
#  'pm-visits-kedarnath-lays-foundation-stone-for-infrastructure-projects.txt',
#  'pm-visits-kerala-dedicates-kollam-bypass-on-nh-66-to-the-nation.txt',
#  'pm-visits-leh-ladakh.txt',
#  'pm-visits-santiniketan-attends-convocation-of-visva-bharati-university-inaugurates-bangladesh-bhavana.txt',
#  'pm-visits-silvassa-in-dadra-nagar-haveli.txt',
#  'pm-visits-vadnagar-launches-intensified-mission-indradhanush-addresses-public-meeting.txt',
#  'pm-wishes-people-of-karnataka-on-sankranti.txt',
#  'pm-wishes-people-on-world-health-day.txt',
#  'pm-wishes-shri-atal-bihari-vajpayee-on-his-birthday-2.txt',
#  'pm-wishes-the-participants-of-khelo-india-youth-games.txt',
#  'pm-witnesses-collective-e-grih-pravesh-lays-foundation-stone-for-development-projects-in-palamu-jharkhand.txt',
#  'pmindia-multilingual-website-now-available-in-13-languages.txt',
#  'pms-address-at-asean-business-investment-summit-manila.txt',
#  'pms-address-at-cancer-institute-adyar-chennai.txt',
#  'pms-address-at-foundation-stone-laying-ceremony-and-dedication-of-multiple-projects-in-kochi.txt',
#  'pms-address-at-groundbreaking-ceremony-of-various-projects-in-uttar-pradesh.txt',
#  'pms-address-at-inaugural-session-of-90th-annual-general-meeting-of-ficci.txt',
#  'pms-address-at-india-rwanda-business-forum-in-kigali-convention-centre-rwanda.txt',
#  'pms-address-at-india-south-africa-business-forum.txt',
#  'pms-address-at-sahkar-sammelan-on-the-occasion-of-birth-centenary-of-laxmanrao-inamdar.txt',
#  'pms-address-at-the-convocation-of-visva-bharti-university-at-santiniketan-in-west-bengal.txt',
#  'pms-address-at-the-cpse-conclave-2018-at-vigyan-bhawan.txt',
#  'pms-address-at-the-foundation-stone-laying-ceremony-of-aiims-madurai-tamil-nadu.txt',
#  'pms-address-at-the-foundation-stone-laying-ceremony-of-vanijya-bhawan.txt',
#  'pms-address-at-the-inaugural-session-of-the-founding-conference-of-international-solar-alliance.txt',
#  'pms-address-at-the-inauguration-of-9th-vibrant-gujarat-summit-2019.txt',
#  'pms-address-at-the-inauguration-of-the-buddha-jayanti-celebrations-in-new-delhi.txt',
#  'pms-address-at-the-international-energy-forum-ministerial-meeting.txt',
#  'pms-address-at-the-opening-ceremony-of-the-third-annual-meeting-of-aiib.txt',
#  'pms-address-at-the-release-of-commemorative-coin-in-honour-of-former-pm-atal-bihari-vajpayee.txt',
#  'pms-address-at-world-food-india-2017.txt',
#  'pms-address-during-his-interaction-with-farmers-across-the-country.txt',
#  'pms-address-in-48th-episode-of-mann-ki-baat.txt',
#  'pms-address-in-50th-episode-of-mann-ki-baat.txt',
#  'pms-address-in-lok-sabha-during-special-discussion-on-the-occasion-of-the-75th-anniversary-of-quit-india-movement.txt',
#  'pms-address-in-parliament-on-the-election-of-shri-harivansh-as-deputy-chairman-of-the-rajya-sabha.txt',
#  'pms-address-on-budget-2019-20.txt',
#  'pms-address-on-the-occasion-of-the-platinum-jubilee-of-the-daily-thanthi-in-chennai.txt',
#  'pms-address-on-the-occasion-of-world-environment-day-2018-at-vigyanbhawan.txt',
#  'pms-address-to-the-nation-from-the-ramparts-of-the-red-fort-on-the-72nd-independence-day.txt',
#  'pms-closing-remarks-at-fourth-meeting-of-the-governing-council-of-niti-aayog.txt',
#  'pms-congratulatory-call-to-president-putin-on-latters-victory-in-the-presidential-elections.txt',
#  'pms-farewell-address-to-the-retiring-members-of-rajya-sabha.txt',
#  'pms-farewell-remarks-to-retiring-rajya-sabha-members.txt',
#  'pms-gifts-to-president-of-myanmar.txt',
#  'pms-interaction-through-pragati-15.txt',
#  'pms-interaction-through-pragati-17.txt',
#  'pms-interaction-through-pragati-18.txt',
#  'pms-interaction-with-itbp-excursion-groups-of-students-from-sikkim-and-ladakh.txt',
#  'pms-interaction-with-medal-winners-of-18th-asian-games.txt',
#  'pms-interaction-with-medal-winners-of-the-commonwealth-games.txt',
#  'pms-interaction-with-young-ias-officers.txt',
#  'pms-interactions-with-directors-and-deputy-secretaries.txt',
#  'pms-intervention-at-the-plenary-session-of-9th-brics-summit-xiamen-china.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-12.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-13.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-14.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-16.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-17.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-18.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-19.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-20.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-21.txt',
#  'pms-mann-ki-baat-programme-on-all-india-radio-8.txt',
#  'pms-meeting-with-global-oil-and-gas-experts-ceos.txt',
#  'pms-message-on-world-toilet-day-2.txt',
#  'pms-message-on-world-toilet-day.txt',
#  'pms-message-on-world-tuberculosis-day.txt',
#  'pms-opening-remarks-at-fourth-meeting-of-governing-council-of-niti-aayog.txt',
#  'pms-opening-statement-at-15th-asean-india-summit-manila.txt',
#  'pms-press-statement-during-his-visit-to-sweden.txt',
#  'pms-press-statement-during-state-visit-of-president-of-belarus.txt',
#  'pms-press-statement-during-state-visit-of-president-of-south-africa-to-india.txt',
#  'pms-press-statement-during-visit-of-prime-minister-of-israel-to-india.txt',
#  'pms-remarks-at-kashi-vishwanath-temple.txt',
#  'pms-remarks-at-the-brics-emerging-markets-and-developing-countries-dialogue-in-xiamen.txt',
#  'pms-remarks-at-the-closing-session-of-the-conference-of-governors.txt',
#  'pms-remarks-at-the-dialogue-with-brics-business-council-in-xiamen-china.txt',
#  'pms-remarks-on-the-election-of-shri-harivansh-as-deputy-chairman-of-the-rajya-sabha.txt',
#  'pms-reply-to-the-motion-of-thanks-on-the-presidents-address-in-the-lok-sabha-2.txt',
#  'pms-speech-at-celebrations-of-the-4th-yoga-day-in-dehradun.txt',
#  'pms-speech-at-event-marking-the-dedication-of-kishanganga-hydro-electric-project-to-the-nation-in-srinagar.txt',
#  'pms-speech-at-pashudhan-arogya-mela-in-shahanshahpur-varanasi.txt',
#  'pms-speech-at-the-birth-centenary-celebrations-of-nanaji-deshmukh-at-iari.txt',
#  'pms-speech-at-the-foundation-stone-laying-ceremony-of-greenfield-airport-for-rajkot-gujarat.txt',
#  'pms-speech-at-the-foundation-stone-laying-ceremony-of-vanijya-bhawan-in-new-delhi.txt',
#  'pms-speech-at-the-inauguration-the-new-building-of-archaeological-survey-of-india.txt',
#  'pms-speech-during-his-interaction-with-the-members-of-self-help-groups-across-the-country-through-video-bridge.txt',
#  'pms-state-visit-to-rwanda-uganda-and-south-africa-july-23-27-2018.txt',
#  'pms-statement-ahead-of-the-beginning-of-the-monsoon-session-of-parliament.txt',
#  'pms-statement-on-terror-attack-in-pulwama.txt',
#  'pms-statement-prior-to-attending-the-g-20-summit.txt',
#  'pms-statement-prior-to-departure-for-republic-of-korea.txt',
#  'pms-statement-prior-to-his-departure-to-nepal-2.txt',
#  'pms-statement-prior-to-his-departure-to-nepal.txt',
#  'pms-statement-prior-to-his-departure-to-philippines.txt',
#  'pms-statement-prior-to-his-departure-to-qingdao-in-china.txt',
#  'pms-statement-prior-to-his-departure-to-russia.txt',
#  'pms-statement-prior-to-his-departure-to-singapore.txt',
#  'pms-statement-prior-to-his-departure-to-sweden-and-uk.txt',
#  'pms-statement-to-media-at-the-start-of-the-winter-session-of-parliament.txt',
#  'pms-telephonic-conversation-with-world-bank-president.txt',
#  'pms-twenty-ninth-interaction-through-pragati.txt',
#  'pms-twenty-seventh-interaction-through-pragati.txt',
#  'pms-twenty-sixth-interaction-through-pragati.txt',
#  'president-elect-of-the-united-nations-general-assembly-calls-on-prime-minister-2.txt',
#  'president-vice-president-pm-offers-floral-tributes-to-sardar-patel-on-his-birth-anniversary-pm-flags-off-run-for-unity.txt',
#  'prime-minister-addresses-the-india-italy-technology-summit.txt',
#  'prime-minister-attends-commemoration-of-75th-anniversary-of-formation-of-azad-hind-government.txt',
#  'prime-minister-chairs-6th-meeting-of-ndma.txt',
#  'prime-minister-has-strongly-disapproved-reported-incidents-of-vandalism-in-parts-of-country.txt',
#  'prime-minister-receives-dr-mohamed-asim-minister-of-foreign-affairs-special-envoy-of-the-president-of-the-republic-of-maldives.txt',
#  'prime-minister-to-address-global-celebrations-of-world-enviroment-day.txt',
#  'prime-minister-to-chair-the-4th-meeting-of-the-governing-council-of-niti-aayog-on-june-17-2018.txt',
#  'prime-minister-to-inaugurate-the-ring-road-and-babatpur-airport-road-in-varanasi-tomorrow.txt',
#  'prime-ministers-keynote-address-at-the-pmnch-partners-forum-in-new-delhi.txt',
#  'status-cum-progress-report-of-special-committee-for-inter-linking-of-rivers.txt',
#  'stephen-harper-former-prime-minister-of-canada-calls-on-the-prime-minister.txt',
#  'the-budget-for-new-india-will-energise-the-nation-says-pm.txt',
#  'uk-india-joint-statement-during-pms-visit-to-uk.txt',
#  'up-cm-donates-rs-five-crore-towards-pmnrf.txt',
#  'us-secretary-of-state-rex-w-tillerson-calls-on-prime-minister.txt',
#  'valedictory-session-of-assistant-secretaries-ias-officers-of-2016-batch-make-presentations-to-pm.txt',
#  'visit-of-president-of-islamic-republic-of-afghanistan-to-india.txt']

# %%
# Combine selected 800 sample speeches into one document for each lang 
parallel_speeches = {}    # STORE TEST SPEECHES
train_speeches = {}       # STORE TRAIN SPEECHES

for lang, speeches in SPEECHES_IN_LANGS.items(): 
  each_lang = []         # list of speeches for one language at a time
  just_train = []
  
  for speech_file in speeches:                          # access list of files in speeches for one language at a time
    with open(speech_file, 'r') as speech:              # read file
      speech = " ".join([str(line) for line in speech]) # each speech file becomes one string

      if speech_file[STRIP_INDEX:] in sample_corpus:
        each_lang.append(speech)                        # append string version of speech file
      else:
        just_train.append(speech)                       # add to train set

  parallel_speeches[lang] = each_lang                   # add list of speeches for every language
  train_speeches[lang] = just_train                     # add to train set

# %% [markdown]
# *Split Parallel Corpus Into Test and Train*

# %%
# Imports
import pandas as pd
from pprint import pprint
import re

# Selecting Train speeches
hindi_unprep = pd.DataFrame(list for list in train_speeches['hi'])
english_unprep = pd.DataFrame(list for list in train_speeches['en'])

# We select speeches with at least 500 tokens
TOKENS_LIMIT = 500
remove = []
for speech in hindi_unprep[:5].itertuples():
  if len(speech[1].split(" "))  < TOKENS_LIMIT:
    remove.append(speech[0])
    print(speech[0], " removed!")

file_name = 'pmindia_hindi_unprep.txt' # SAVE FILE AS

# Save trainset - not used
with open(file_name, 'w', encoding = "utf-8") as f:     
  f.writelines("%s" % str(line)+"\t" for line in train_speeches['hi'])

x = open(file_name, "r", encoding = "utf-8")

# View each row as a speech
hindi_unprep[:5]
# Out:
# 0  removed!
# 1  removed!
# 2  removed!
# 3  removed!
#                                                    0
# 0  नागरिकों से स्‍वच्‍छाग्रही बनने और स्‍वच्‍छ भा...
# 1  श्री सोमनाथ न्‍यास के न्‍यासियों की 116वीं बैठ...
# 2  प्रधानमंत्री श्री नरेन्द्र मोदी की अध्यक्षता म...
# 3  प्रधानमंत्री श्री नरेन्द्र मोदी ने आज ही के दि...
# 4  · खूंटी की जिला अदालत में छत पर लगने वाले सौर ...

# %% [markdown]
# ## Training Models
#
# ###**Hindi-Based ZeroshotTM**
#
# *Preprocessing*
#
# Why do we use the preprocessed text here? We need text without punctuation to build the bag of word. Also, we might want only to have the most frequent words inside the BoW. Too many words might not help.

# %%
### HINDI ###
LANG_SELECTED = 'hi'

# We select 500 tokens per speech
NUM_TOKENS = 200 

# Download Hindi Stopwords
# !pip install stopwordsiso
import stopwordsiso as stopwords

# Run preprocessing script
documents = [line[:NUM_TOKENS].strip() for line in train_speeches[LANG_SELECTED]]
sp = WhiteSpacePreprocessingStopwords(documents, stopwords_list = stopwords.stopwords(LANG_SELECTED))
preprocessed_documents, unpreprocessed_corpus, vocab = sp.preprocess()

# Ensure same length for preprocessed and unpreprocessed
print(len(preprocessed_documents), len(unpreprocessed_corpus))

# %% [markdown]
# We don't discard the non-preprocessed hindi texts, because we are going to use them as input for obtaining the **contextualized** document representations. We will now pass our files with preprocess and unpreprocessed data to our TopicModelDataPreparation object. This object takes care of creating the bag of words and obtains the contextualized BERT representations of documents. This operation allows us to create our training dataset.
#
# Note: Here we use the contextualized model "ai4bharat/indic-bert", because we need a multilingual model for indic languages for performing cross-lingual predictions later.

# %% [markdown]
# *Training ZeroshotTM*

# %%
# Imports
from contextualized_topic_models.models.ctm import ZeroShotTM
import contextualized_topic_models.utils.data_preparation
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk
import pickle

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

def bert_embeddings_from_file(text_file, sbert_model_to_load, custom=False, tokenizer_args=None, model_args=None, batch_size=200):
    """
    Creates SBERT Embeddings from an input file
    """
    from sentence_transformers import SentenceTransformer, models

    # For indicBERT
    if sbert_model_to_load == 'ai4bharat/indic-bert':
      custom = True
      tokenizer_args = {"keep_accents": True}

    # If build custom sentence transformer model
    if custom:
      if tokenizer_args and model_args:   # both set of arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, 
                                                  tokenizer_args=tokenizer_args, 
                                                  model_args = model_args)
      
      elif tokenizer_args:   # tokenizer arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, tokenizer_args = tokenizer_args)

      elif model_args:   # model arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, model_args = model_args)
      
      else:
        word_embedding_model = models.Transformer(sbert_model_to_load)

      # Pass modules to build sentence transformer model
      pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
      model = SentenceTransformer(modules=[word_embedding_model, pooling_model])   
    
    # Else retrieve model from hugging face
    else:
        model = SentenceTransformer(sbert_model_to_load)

    with open(text_file, encoding="utf-8") as filino:
        train_text = list(map(lambda x: x, filino.readlines()))

    return np.array(model.encode(train_text, show_progress_bar=True, batch_size=batch_size))


def bert_embeddings_from_list(texts, sbert_model_to_load, custom=False, tokenizer_args=None, model_args=None, batch_size=200):
    """
    Creates SBERT Embeddings from a list
    """
    from sentence_transformers import SentenceTransformer, models

    # For indicBERT
    if sbert_model_to_load == 'ai4bharat/indic-bert':
      custom = True
      tokenizer_args = {"keep_accents": True}

    # If build custom sentence transformer model
    if custom:
      if tokenizer_args and model_args:   # both set of arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, 
                                                  tokenizer_args=tokenizer_args, 
                                                  model_args = model_args)
      
      elif tokenizer_args:   # tokenizer arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, tokenizer_args = tokenizer_args)

      elif model_args:   # model arguments given in dict to pass into hugging face model
        word_embedding_model = models.Transformer(sbert_model_to_load, model_args = model_args)
      
      else:
        word_embedding_model = models.Transformer(sbert_model_to_load)

      # Pass modules to build sentence transformer model
      pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
      model = SentenceTransformer(modules=[word_embedding_model, pooling_model])   
    
    # Else retrieve model from hugging face
    else:
        model = SentenceTransformer(sbert_model_to_load)

    return np.array(model.encode(texts, show_progress_bar=True, batch_size=batch_size))

contextualized_topic_models.utils.data_preparation.bert_embeddings_from_file = bert_embeddings_from_file
contextualized_topic_models.utils.data_preparation.bert_embeddings_from_list = bert_embeddings_from_list

# %%
sbert_model_to_load = 'ai4bharat/indic-bert'
tokenizer_args = {"keep_accents": True}
model_args = {}

word_embedding_model = models.Transformer(sbert_model_to_load, 
                                                  tokenizer_args=tokenizer_args, 
                                                  model_args = model_args)

pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension())
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Some weights of the model checkpoint at ai4bharat/indic-bert were not used when initializing AlbertModel: ['predictions.dense.bias', 'sop_classifier.classifier.bias', 'sop_classifier.classifier.weight', 'predictions.bias', 'predictions.LayerNorm.weight', 'predictions.decoder.bias', 'predictions.decoder.weight', 'predictions.dense.weight', 'predictions.LayerNorm.bias']
# - This IS expected if you are initializing AlbertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
print(model.tokenizer.tokenize("यहाँ") == model.tokenizer.tokenize("यह"))
# Out:
# False

# %%
# Load Indic Multilingual embeddings 
tp = TopicModelDataPreparation('ai4bharat/indic-bert')

# Building training dataset
training_dataset = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)

# %%
# Train over 100 epochs

### HINDI : 25 TOPICS ###
z_ctm_25_HI = ZeroShotTM(bow_size=len(tp.vocab), n_components = 25, contextual_size=768, num_epochs=100)

z_ctm_25_HI.fit(training_dataset, n_samples = 100) # run the model
z_ctm_25_HI.save("./") # save the model

# ### HINDI : 50 TOPICS ###
z_ctm_50_HI = ZeroShotTM(bow_size=len(tp.vocab), n_components = 50, contextual_size=768, num_epochs=100)

z_ctm_50_HI.fit(training_dataset, n_samples = 100) # run the model
z_ctm_50_HI.save("./") # save the model

# %%
# See topic predictions per speech doc
z_ctm_25_HI.get_topic_lists(5)
# Out:
# [['दश', 'बजट', 'करन', 'रलव', 'सतर'],
#  ['उठ', 'उच', 'तपस', 'नह', 'बढग'],
#  ['मर', 'मच', 'कदर', 'जय', 'बहत'],
#  ['बहत', 'मन', 'हम', 'मझ', 'पहल'],
#  ['नरनदर', 'हए', 'आज', 'नई', 'करत'],
#  ['एव', 'परबधन', 'सरकषण', 'तहत', 'जल'],
#  ['कषतर', 'एमओय', 'एव', 'पतर', 'परयटन'],
#  ['करग', 'उच', 'उठ', 'तपस', 'बढग'],
#  ['हमल', 'हए', 'हम', 'करत', 'वयकत'],
#  ['रपय', 'गई', 'रपए', 'अनगरह', 'दन'],
#  ['बहत', 'मझ', 'हम', 'दश', 'आपक'],
#  ['in', 'http', 'अपन', 'of', 'to'],
#  ['तहत', 'वरष', 'करन', 'इसस', 'पद'],
#  ['आज', 'हए', 'नरनदर', 'करत', 'अवसर'],
#  ['कषतर', 'एव', 'एमओय', 'पतर', 'परयटन'],
#  ['दश', 'रह', 'आज', 'अमर', 'हम'],
#  ['मझ', 'बहत', 'मन', 'पहल', 'आपक'],
#  ['रल', 'परदश', 'चरण', 'एकड', 'आधर'],
#  ['उनक', 'उठ', 'उच', 'तपस', 'टस'],
#  ['अवसर', 'सदश', 'नमन', 'अपन', 'गर'],
#  ['सफल', 'परकषपण', 'उठ', 'उच', 'बढग'],
#  ['आज', 'हम', 'करत', 'अवसर', 'अपन'],
#  ['बठक', 'सयकत', 'सममलन', 'नरनदर', 'हई'],
#  ['करन', 'मदद', 'पश', 'दन', 'इसक'],
#  ['मझ', 'आपक', 'मर', 'excellency', 'मरकल']]

# %%
# See topic predictions per speech doc
z_ctm_50_HI.get_topic_lists(5)
# Out:
# [['पतर', 'एमओय', 'कषतर', 'उपकरण', 'एव'],
#  ['दश', 'रह', 'मर', 'आज', 'जय'],
#  ['दश', 'बहत', 'आज', 'हम', 'कछ'],
#  ['तहत', 'वरष', 'करन', 'वतन', 'इसक'],
#  ['अपन', 'फसबक', 'सममलन', 'mygov', 'http'],
#  ['मझ', 'मर', 'media', 'economic', 'excellency'],
#  ['हए', 'नरनदर', 'करत', 'अवसर', 'रप'],
#  ['बहत', 'मझ', 'आज', 'मर', 'दश'],
#  ['नरनदर', 'शख', 'उनह', 'अबदल', 'अल'],
#  ['रपय', 'गई', 'तहत', 'एकड', 'इसक'],
#  ['करत', 'हम', 'नमन', 'शत', 'अवसर'],
#  ['बहत', 'मझ', 'हम', 'दश', 'रप'],
#  ['बठक', 'गई', 'करन', 'सख', 'हई'],
#  ['हए', 'करत', 'आज', 'नरनदर', 'अवसर'],
#  ['अवसर', 'हम', 'खल', 'अपन', 'सदश'],
#  ['मर', 'कदर', 'ससद', 'एन', 'मझ'],
#  ['बहत', 'आज', 'दश', 'हम', 'हए'],
#  ['कषतर', 'मदद', 'इसस', 'एव', 'पतर'],
#  ['of', 'the', 'and', 'to', 'in'],
#  ['आज', 'हए', 'करत', 'अवसर', 'नई'],
#  ['करन', 'मदद', 'इसस', 'आय', 'घरल'],
#  ['करन', 'गई', 'तहत', 'रपय', 'दन'],
#  ['सदश', 'सफल', 'परकषपण', 'अपन', 'गरव'],
#  ['मन', 'मझ', 'कछ', 'हआ', 'पहल'],
#  ['मध', 'उजबक', 'तपस', 'जलम', 'अधर'],
#  ['कषतर', 'एव', 'एमओय', 'जल', 'परबधन'],
#  ['हई', 'बस', 'गए', 'दख', 'सभव'],
#  ['ऑफ', 'एड', 'नशनल', 'तल', 'ऑयल'],
#  ['सममलन', 'बठक', 'सयकत', 'नरनदर', 'रस'],
#  ['रपय', 'गई', 'अतरगत', 'तहत', 'करन'],
#  ['मध', 'तपस', 'जलम', 'आच', 'टड'],
#  ['कषतर', 'एव', 'एमओय', 'पतर', 'गए'],
#  ['दश', 'बजट', 'रलव', 'सतर', 'करन'],
#  ['मझ', 'आपक', 'रप', 'सबध', 'बहत'],
#  ['अवसर', 'सदश', 'नमन', 'अपन', 'खल'],
#  ['हम', 'करत', 'हए', 'दश', 'आज'],
#  ['आज', 'हए', 'करत', 'करन', 'नई'],
#  ['हए', 'हमल', 'वयकत', 'दख', 'भकप'],
#  ['आज', 'नरनदर', 'हए', 'करत', 'नई'],
#  ['बठक', 'कल', 'रल', 'परदश', 'सख'],
#  ['बठक', 'सयकत', 'नई', 'अरब', 'सह'],
#  ['मध', 'तपस', 'करग', 'टड', 'जलम'],
#  ['मझ', 'बहत', 'मन', 'पहल', 'कछ'],
#  ['तपस', 'मध', 'जलम', 'उजबक', 'अर'],
#  ['दश', 'रह', 'अमर', 'आज', 'हम'],
#  ['उनक', 'एम', 'परव', 'लखक', 'अययर'],
#  ['रल', 'परदश', 'कल', 'आधर', 'करग'],
#  ['मर', 'रह', 'जय', 'दश', 'मच'],
#  ['मर', 'मझ', 'बहत', 'अनय', 'पहल'],
#  ['करन', 'तहत', 'नरदर', 'इसस', 'सदसय']]

# %% [markdown]
# ###**English-Based ZeroshotTM**
#
# *Preprocessing*
#
# Why do we use the preprocessed text here? We need text without punctuation to build the bag of word. Also, we might want only to have the most frequent words inside the BoW. Too many words might not help.

# %%
### ENGLISH ###
LANG_SELECTED = 'en'

# We select 500 tokens per speech
NUM_TOKENS = 500 

# Download English Stopwords
nltk.download('stopwords')

# Run preprocessing script
documents = [line[:NUM_TOKENS].strip() for line in train_speeches[LANG_SELECTED]]
sp = WhiteSpacePreprocessingStopwords(documents, stopwords_list = stopwords.stopwords(LANG_SELECTED))
preprocessed_documents, unpreprocessed_corpus, vocab = sp.preprocess()

# Ensure same length for preprocessed and unpreprocessed
print(len(preprocessed_documents), len(unpreprocessed_corpus))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 4489 4489
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# We don't discard the non-preprocessed english texts, because we are going to use them as input for obtaining the **contextualized** document representations. We will now pass our files with preprocess and unpreprocessed data to our TopicModelDataPreparation object. This object takes care of creating the bag of words and obtains the contextualized BERT representations of documents. This operation allows us to create our training dataset.
#
# Note: Here we use the contextualized model "ai4bharat/indic-bert", because we need a multilingual model for indic languages for performing cross-lingual predictions later.

# %%
# Building training dataset
tp = TopicModelDataPreparation("ai4bharat/indic-bert")
en_training = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.77k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# *Training ZeroshotTM*

# %%
# Train over 100 epochs

### ENGLISH : 25 TOPICS ###
z_ctm_25_EN = ZeroShotTM(bow_size=len(tp.vocab), n_components = 25, contextual_size=768, num_epochs=100)
z_ctm_25_EN.fit(en_training) # run the model
z_ctm_25_EN.save("./") # save the model

### ENGLISH : 50 TOPICS ###
z_ctm_50_EN = ZeroShotTM(bow_size=len(tp.vocab), n_components = 50, contextual_size=768, num_epochs=100)
z_ctm_50_EN.fit(en_training) # run the model
z_ctm_50_EN.save("./") # save the model

# %%
# See topic predictions per speech doc
z_ctm_25_EN.get_topic_lists(5)
# Out:
# [['excellency', 'media', 'delighted', 'distinguished', 'friends'],
#  ['day', 'indian', 'congratulated', 'salute', 'winning'],
#  ['prime', 'minister', 'modi', 'called', 'india'],
#  ['मर', 'पर', 'और', 'मच', 'जय'],
#  ['scientists', 'satellite', 'bharat', 'isro', 'launch'],
#  ['हम', 'एक', 'और', 'आज', 'बहत'],
#  ['और', 'आज', 'एक', 'बहत', 'पर'],
#  ['people', 'day', 'greeted', 'wishes', 'occasion'],
#  ['और', 'पर', 'मर', 'हम', 'आप'],
#  ['mou', 'cooperation', 'understanding', 'memorandum', 'approval'],
#  ['budget', 'time', 'namaskar', 'countrymen', 'baat'],
#  ['mou', 'cooperation', 'understanding', 'union', 'memorandum'],
#  ['cabinet', 'land', 'union', 'chaired', 'approval'],
#  ['shri', 'meeting', 'chief', 'minister', 'government'],
#  ['पर', 'हम', 'और', 'एक', 'इस'],
#  ['cabinet', 'central', 'union', 'chaired', 'approval'],
#  ['governance', 'interaction', 'based', 'progress', 'implementation'],
#  ['yojana', 'development', 'scheme', 'crore', 'pradhan'],
#  ['india', 'summit', 'visit', 'president', 'japan'],
#  ['lives', 'condoled', 'loss', 'families', 'condolences'],
#  ['anniversary', 'birth', 'paid', 'tributes', 'ji'],
#  ['visited', 'foundation', 'mark', 'stone', 'unveiled'],
#  ['minister', 'prime', 'attack', 'nepal', 'afghanistan'],
#  ['union', 'cabinet', 'chaired', 'amendment', 'approval'],
#  ['agreement', 'countries', 'india', 'trade', 'signing']]

# %%
# See topic predictions per speech doc
z_ctm_50_EN.get_topic_lists(5)
# Out:
# [['land', 'cabinet', 'union', 'acres', 'institutes'],
#  ['minister', 'prime', 'modi', 'nepal', 'narendra'],
#  ['आप', 'आज', 'पर', 'इस', 'रह'],
#  ['radio', 'share', 'programme', 'invited', 'mygov'],
#  ['day', 'salute', 'saluted', 'personnel', 'armed'],
#  ['condoled', 'life', 'shri', 'passing', 'demise'],
#  ['called', 'interacted', 'secretaries', 'development', 'delegation'],
#  ['people', 'greeted', 'day', 'occasion', 'auspicious'],
#  ['और', 'आज', 'पर', 'एक', 'रप'],
#  ['crore', 'rs', 'project', 'cost', 'approved'],
#  ['progress', 'infrastructure', 'projects', 'sectors', 'reviewed'],
#  ['cabinet', 'union', 'chaired', 'approved', 'crore'],
#  ['minister', 'prime', 'modi', 'called', 'bilateral'],
#  ['central', 'pay', 'cabinet', 'approved', 'chaired'],
#  ['ससद', 'और', 'कदर', 'सदन', 'परदश'],
#  ['lives', 'loss', 'expressed', 'families', 'injured'],
#  ['occasion', 'book', 'speaking', 'shri', 'released'],
#  ['union', 'agreement', 'chaired', 'cabinet', 'approved'],
#  ['demise', 'condoled', 'passing', 'family', 'condolences'],
#  ['mou', 'bilateral', 'cooperation', 'india', 'signed'],
#  ['cooperation', 'ministry', 'signed', 'republic', 'mou'],
#  ['mou', 'cooperation', 'union', 'cabinet', 'chaired'],
#  ['delhi', 'addressed', 'movement', 'day', 'bharat'],
#  ['brics', 'leaders', 'global', 'business', 'happy'],
#  ['rs', 'relief', 'fund', 'flood', 'situation'],
#  ['anniversary', 'birth', 'paid', 'tributes', 'bow'],
#  ['shri', 'meeting', 'chief', 'minister', 'situation'],
#  ['development', 'national', 'energy', 'policy', 'ministry'],
#  ['policy', 'union', 'sector', 'chaired', 'amendments'],
#  ['visit', 'foundation', 'visited', 'inaugurate', 'tomorrow'],
#  ['people', 'ties', 'india', 'day', 'independence'],
#  ['countrymen', 'namaskar', 'time', 'season', 'month'],
#  ['congratulated', 'winning', 'team', 'gold', 'cup'],
#  ['और', 'मझ', 'बहत', 'मर', 'आज'],
#  ['scientists', 'successful', 'launch', 'isro', 'pslv'],
#  ['summit', 'leaders', 'global', 'india', 'ceos'],
#  ['afghanistan', 'attack', 'terrorist', 'terror', 'condemned'],
#  ['constitution', 'union', 'central', 'commission', 'amendment'],
#  ['cooperation', 'mou', 'agreement', 'countries', 'india'],
#  ['mou', 'union', 'chaired', 'memorandum', 'cabinet'],
#  ['हम', 'और', 'यह', 'कछ', 'एक'],
#  ['excellency', 'media', 'president', 'delighted', 'friends'],
#  ['launched', 'nation', 'dedicated', 'yojana', 'scheme'],
#  ['और', 'इस', 'पर', 'आज', 'एक'],
#  ['agreement', 'climate', 'change', 'trade', 'investment'],
#  ['meeting', 'ministers', 'secretaries', 'governance', 'implementation'],
#  ['बहत', 'आप', 'और', 'मर', 'मझ'],
#  ['visit', 'president', 'republic', 'prime', 'minister'],
#  ['mou', 'cooperation', 'union', 'chaired', 'cabinet'],
#  ['budget', 'poor', 'yojana', 'schemes', 'money']]

# %% [markdown]
# ## Predictions and Evaluation
# ###**Unseen Multilingual  Corpora Predictions**
#
# *Languages*
#
# * Assamese - as
# * Bengali - bn
# * English - en
# * Gujarati - gu
# * Hindi - hi
# * Kannada - kn
# * Malayalam - ml
# * Marathi - mr
# * Oriya - or
# * Punjabi - pa
# * Tamil - ta
# * Telugu - te

# %%
# Convert test files into test datasets
as_testset = tp.transform(parallel_speeches['as'])
bn_testset = tp.transform(parallel_speeches['bn'])
en_testset = tp.transform(parallel_speeches['en'])
gu_testset = tp.transform(parallel_speeches['gu'])
hi_testset = tp.transform(parallel_speeches['hi'])
kn_testset = tp.transform(parallel_speeches['kn'])
ml_testset = tp.transform(parallel_speeches['ml'])
mr_testset = tp.transform(parallel_speeches['mr'])
or_testset = tp.transform(parallel_speeches['or'])
pa_testset = tp.transform(parallel_speeches['pa'])
ta_testset = tp.transform(parallel_speeches['ta'])
te_testset = tp.transform(parallel_speeches['te'])

# %% [markdown]
# ###**Topic Predictions**
#
# *Hindi*

# %%
### HINDI : 25 TOPIC PREDICTIONS ### 
as_topics_predictions = z_ctm_25_HI.get_thetas(as_testset, n_samples=100) # get all the topic predictions
bn_topics_predictions = z_ctm_25_HI.get_thetas(bn_testset, n_samples=100) # get all the topic predictions
en_topics_predictions = z_ctm_25_HI.get_thetas(en_testset, n_samples=100) # get all the topic predictions
gu_topics_predictions = z_ctm_25_HI.get_thetas(gu_testset, n_samples=100) # get all the topic predictions
hi_topics_predictions = z_ctm_25_HI.get_thetas(hi_testset, n_samples=100) # get all the topic predictions
kn_topics_predictions = z_ctm_25_HI.get_thetas(kn_testset, n_samples=100) # get all the topic predictions
ml_topics_predictions = z_ctm_25_HI.get_thetas(ml_testset, n_samples=100) # get all the topic predictions
mr_topics_predictions = z_ctm_25_HI.get_thetas(mr_testset, n_samples=100) # get all the topic predictions
or_topics_predictions = z_ctm_25_HI.get_thetas(or_testset, n_samples=100) # get all the topic predictions
pa_topics_predictions = z_ctm_25_HI.get_thetas(pa_testset, n_samples=100) # get all the topic predictions
ta_topics_predictions = z_ctm_25_HI.get_thetas(ta_testset, n_samples=100) # get all the topic predictions
te_topics_predictions = z_ctm_25_HI.get_thetas(te_testset, n_samples=100) # get all the topic predictions

topics_25_HI = {'as': as_topics_predictions, 'bn': bn_topics_predictions, 
             'en': en_topics_predictions, 'gu': gu_topics_predictions,
             'hi': hi_topics_predictions, 'kn': kn_topics_predictions,
             'ml': ml_topics_predictions, 'mr': mr_topics_predictions,
             'or': or_topics_predictions, 'pa': pa_topics_predictions,
             'ta': ta_topics_predictions, 'te': te_topics_predictions}

# %%
### HINDI : 50 TOPIC PREDICTIONS ### 
as_topics_predictions = z_ctm_50_HI.get_thetas(as_testset, n_samples=100) # get all the topic predictions
bn_topics_predictions = z_ctm_50_HI.get_thetas(bn_testset, n_samples=100) # get all the topic predictions
en_topics_predictions = z_ctm_50_HI.get_thetas(en_testset, n_samples=100) # get all the topic predictions
gu_topics_predictions = z_ctm_50_HI.get_thetas(gu_testset, n_samples=100) # get all the topic predictions
hi_topics_predictions = z_ctm_50_HI.get_thetas(hi_testset, n_samples=100) # get all the topic predictions
kn_topics_predictions = z_ctm_50_HI.get_thetas(kn_testset, n_samples=100) # get all the topic predictions
ml_topics_predictions = z_ctm_50_HI.get_thetas(ml_testset, n_samples=100) # get all the topic predictions
mr_topics_predictions = z_ctm_50_HI.get_thetas(mr_testset, n_samples=100) # get all the topic predictions
or_topics_predictions = z_ctm_50_HI.get_thetas(or_testset, n_samples=100) # get all the topic predictions
pa_topics_predictions = z_ctm_50_HI.get_thetas(pa_testset, n_samples=100) # get all the topic predictions
ta_topics_predictions = z_ctm_50_HI.get_thetas(ta_testset, n_samples=100) # get all the topic predictions
te_topics_predictions = z_ctm_50_HI.get_thetas(te_testset, n_samples=100) # get all the topic predictions

topics_50_HI = {'as': as_topics_predictions, 'bn': bn_topics_predictions, 
             'en': en_topics_predictions, 'gu': gu_topics_predictions,
             'hi': hi_topics_predictions, 'kn': kn_topics_predictions,
             'ml': ml_topics_predictions, 'mr': mr_topics_predictions,
             'or': or_topics_predictions, 'pa': pa_topics_predictions,
             'ta': ta_topics_predictions, 'te': te_topics_predictions}

# %% [markdown]
# *English*

# %%
### ENGLISH : 25 TOPIC PREDICTIONS ### 
as_topics_predictions = z_ctm_25_EN.get_thetas(as_testset, n_samples=100) # get all the topic predictions
bn_topics_predictions = z_ctm_25_EN.get_thetas(bn_testset, n_samples=100) # get all the topic predictions
en_topics_predictions = z_ctm_25_EN.get_thetas(en_testset, n_samples=100) # get all the topic predictions
gu_topics_predictions = z_ctm_25_EN.get_thetas(gu_testset, n_samples=100) # get all the topic predictions
hi_topics_predictions = z_ctm_25_EN.get_thetas(hi_testset, n_samples=100) # get all the topic predictions
kn_topics_predictions = z_ctm_25_EN.get_thetas(kn_testset, n_samples=100) # get all the topic predictions
ml_topics_predictions = z_ctm_25_EN.get_thetas(ml_testset, n_samples=100) # get all the topic predictions
mr_topics_predictions = z_ctm_25_EN.get_thetas(mr_testset, n_samples=100) # get all the topic predictions
or_topics_predictions = z_ctm_25_EN.get_thetas(or_testset, n_samples=100) # get all the topic predictions
pa_topics_predictions = z_ctm_25_EN.get_thetas(pa_testset, n_samples=100) # get all the topic predictions
ta_topics_predictions = z_ctm_25_EN.get_thetas(ta_testset, n_samples=100) # get all the topic predictions
te_topics_predictions = z_ctm_25_EN.get_thetas(te_testset, n_samples=100) # get all the topic predictions

topics_25_EN = {'as': as_topics_predictions, 'bn': bn_topics_predictions, 
             'en': en_topics_predictions, 'gu': gu_topics_predictions,
             'hi': hi_topics_predictions, 'kn': kn_topics_predictions,
             'ml': ml_topics_predictions, 'mr': mr_topics_predictions,
             'or': or_topics_predictions, 'pa': pa_topics_predictions,
             'ta': ta_topics_predictions, 'te': te_topics_predictions}

# %%
### ENGLISH : 50 TOPIC PREDICTIONS ### 
as_topics_predictions = z_ctm_50_EN.get_thetas(as_testset, n_samples=100) # get all the topic predictions
bn_topics_predictions = z_ctm_50_EN.get_thetas(bn_testset, n_samples=100) # get all the topic predictions
en_topics_predictions = z_ctm_50_EN.get_thetas(en_testset, n_samples=100) # get all the topic predictions
gu_topics_predictions = z_ctm_50_EN.get_thetas(gu_testset, n_samples=100) # get all the topic predictions
hi_topics_predictions = z_ctm_50_EN.get_thetas(hi_testset, n_samples=100) # get all the topic predictions
kn_topics_predictions = z_ctm_50_EN.get_thetas(kn_testset, n_samples=100) # get all the topic predictions
ml_topics_predictions = z_ctm_50_EN.get_thetas(ml_testset, n_samples=100) # get all the topic predictions
mr_topics_predictions = z_ctm_50_EN.get_thetas(mr_testset, n_samples=100) # get all the topic predictions
or_topics_predictions = z_ctm_50_EN.get_thetas(or_testset, n_samples=100) # get all the topic predictions
pa_topics_predictions = z_ctm_50_EN.get_thetas(pa_testset, n_samples=100) # get all the topic predictions
ta_topics_predictions = z_ctm_50_EN.get_thetas(ta_testset, n_samples=100) # get all the topic predictions
te_topics_predictions = z_ctm_50_EN.get_thetas(te_testset, n_samples=100) # get all the topic predictions

topics_50_EN = {'as': as_topics_predictions, 'bn': bn_topics_predictions, 
             'en': en_topics_predictions, 'gu': gu_topics_predictions,
             'hi': hi_topics_predictions, 'kn': kn_topics_predictions,
             'ml': ml_topics_predictions, 'mr': mr_topics_predictions,
             'or': or_topics_predictions, 'pa': pa_topics_predictions,
             'ta': ta_topics_predictions, 'te': te_topics_predictions}

# %% [markdown]
# **Quantitative Evaluation**

# %%
# Import metrics
from contextualized_topic_models.evaluation.measures import Matches, KLDivergence, CentroidDistance
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. **Matches**
#
# > Matches is the % of times the predicted topic for the non-English test document is the same as for the respective test document in English. The higher the scores, the better.

# %% [markdown]
# *Hindi*

# %%
# HINDI : Matches for 25 topics
hi_as_matches = Matches(topics_25_HI['hi'], topics_25_HI['as'])
hi_bn_matches = Matches(topics_25_HI['hi'], topics_25_HI['bn'])
hi_en_matches = Matches(topics_25_HI['hi'], topics_25_HI['en'])
hi_gu_matches = Matches(topics_25_HI['hi'], topics_25_HI['gu'])
hi_kn_matches = Matches(topics_25_HI['hi'], topics_25_HI['kn'])
hi_ml_matches = Matches(topics_25_HI['hi'], topics_25_HI['ml'])
hi_mr_matches = Matches(topics_25_HI['hi'], topics_25_HI['mr'])
hi_or_matches = Matches(topics_25_HI['hi'], topics_25_HI['or'])
hi_pa_matches = Matches(topics_25_HI['hi'], topics_25_HI['pa'])
hi_ta_matches = Matches(topics_25_HI['hi'], topics_25_HI['ta'])
hi_te_matches = Matches(topics_25_HI['hi'], topics_25_HI['te'])


matches_25_HI = {'as': hi_as_matches.score(), 'bn': hi_bn_matches.score(), 
             'en': hi_en_matches.score(), 'gu': hi_gu_matches.score(),
             'kn': hi_kn_matches.score(),
             'ml': hi_ml_matches.score(), 'mr': hi_mr_matches.score(),
             'or': hi_or_matches.score(), 'pa': hi_pa_matches.score(),
             'ta': hi_ta_matches.score(), 'te': hi_te_matches.score()}
matches_25_HI
# Out:
# {'as': 0.7875,
#  'bn': 0.7725,
#  'en': 0.78625,
#  'gu': 0.79125,
#  'kn': 0.72125,
#  'ml': 0.655,
#  'mr': 0.8425,
#  'or': 0.58375,
#  'pa': 0.77125,
#  'ta': 0.70125,
#  'te': 0.7925}

# %%
# HINDI : Matches for 50 topics
hi_as_matches = Matches(topics_50_HI['hi'], topics_50_HI['as'])
hi_bn_matches = Matches(topics_50_HI['hi'], topics_50_HI['bn'])
hi_en_matches = Matches(topics_50_HI['hi'], topics_50_HI['en'])
hi_gu_matches = Matches(topics_50_HI['hi'], topics_50_HI['gu'])
hi_kn_matches = Matches(topics_50_HI['hi'], topics_50_HI['kn'])
hi_ml_matches = Matches(topics_50_HI['hi'], topics_50_HI['ml'])
hi_mr_matches = Matches(topics_50_HI['hi'], topics_50_HI['mr'])
hi_or_matches = Matches(topics_50_HI['hi'], topics_50_HI['or'])
hi_pa_matches = Matches(topics_50_HI['hi'], topics_50_HI['pa'])
hi_ta_matches = Matches(topics_50_HI['hi'], topics_50_HI['ta'])
hi_te_matches = Matches(topics_50_HI['hi'], topics_50_HI['te'])


matches_50_HI = {'as': hi_as_matches.score(), 'bn': hi_bn_matches.score(), 
             'en': hi_en_matches.score(), 'gu': hi_gu_matches.score(),
             'kn': hi_kn_matches.score(),
             'ml': hi_ml_matches.score(), 'mr': hi_mr_matches.score(),
             'or': hi_or_matches.score(), 'pa': hi_pa_matches.score(),
             'ta': hi_ta_matches.score(), 'te': hi_te_matches.score()}
matches_50_HI
# Out:
# {'as': 0.33625,
#  'bn': 0.56875,
#  'en': 0.61,
#  'gu': 0.6625,
#  'kn': 0.59125,
#  'ml': 0.58625,
#  'mr': 0.67,
#  'or': 0.6075,
#  'pa': 0.61375,
#  'ta': 0.55125,
#  'te': 0.4125}

# %% [markdown]
# *English*

# %%
# ENGLISH : Matches for 25 topics
en_as_matches = Matches(topics_25_EN['en'], topics_25_EN['as'])
en_bn_matches = Matches(topics_25_EN['en'], topics_25_EN['bn'])
en_hi_matches = Matches(topics_25_EN['en'], topics_25_EN['hi'])
en_gu_matches = Matches(topics_25_EN['en'], topics_25_EN['gu'])
en_kn_matches = Matches(topics_25_EN['en'], topics_25_EN['kn'])
en_ml_matches = Matches(topics_25_EN['en'], topics_25_EN['ml'])
en_mr_matches = Matches(topics_25_EN['en'], topics_25_EN['mr'])
en_or_matches = Matches(topics_25_EN['en'], topics_25_EN['or'])
en_pa_matches = Matches(topics_25_EN['en'], topics_25_EN['pa'])
en_ta_matches = Matches(topics_25_EN['en'], topics_25_EN['ta'])
en_te_matches = Matches(topics_25_EN['en'], topics_25_EN['te'])


matches_25_EN = {'as': en_as_matches.score(), 'bn': en_bn_matches.score(), 
             'en': en_hi_matches.score(), 'gu': en_gu_matches.score(),
             'kn': en_kn_matches.score(),
             'ml': en_ml_matches.score(), 'mr': en_mr_matches.score(),
             'or': en_or_matches.score(), 'pa': en_pa_matches.score(),
             'ta': en_ta_matches.score(), 'te': en_te_matches.score()}
matches_25_EN
# Out:
# {'as': 0.0825,
#  'bn': 0.30875,
#  'en': 0.66625,
#  'gu': 0.5725,
#  'kn': 0.365,
#  'ml': 0.33875,
#  'mr': 0.61125,
#  'or': 0.20625,
#  'pa': 0.4275,
#  'ta': 0.41375,
#  'te': 0.2475}

# %%
# ENGLISH : Matches for 50 topics
en_as_matches = Matches(topics_50_EN['en'], topics_50_EN['as'])
en_bn_matches = Matches(topics_50_EN['en'], topics_50_EN['bn'])
en_en_matches = Matches(topics_50_EN['en'], topics_50_EN['hi'])
en_gu_matches = Matches(topics_50_EN['en'], topics_50_EN['gu'])
en_kn_matches = Matches(topics_50_EN['en'], topics_50_EN['kn'])
en_ml_matches = Matches(topics_50_EN['en'], topics_50_EN['ml'])
en_mr_matches = Matches(topics_50_EN['en'], topics_50_EN['mr'])
en_or_matches = Matches(topics_50_EN['en'], topics_50_EN['or'])
en_pa_matches = Matches(topics_50_EN['en'], topics_50_EN['pa'])
en_ta_matches = Matches(topics_50_EN['en'], topics_50_EN['ta'])
en_te_matches = Matches(topics_50_EN['en'], topics_50_EN['te'])


matches_50_EN = {'as': en_as_matches.score(), 'bn': en_bn_matches.score(), 
             'en': en_hi_matches.score(), 'gu': en_gu_matches.score(),
             'kn': en_kn_matches.score(),
             'ml': en_ml_matches.score(), 'mr': en_mr_matches.score(),
             'or': en_or_matches.score(), 'pa': en_pa_matches.score(),
             'ta': en_ta_matches.score(), 'te': en_te_matches.score()}
matches_50_EN
# Out:
# {'as': 0.03625,
#  'bn': 0.2225,
#  'en': 0.66625,
#  'gu': 0.4875,
#  'kn': 0.31375,
#  'ml': 0.29625,
#  'mr': 0.53125,
#  'or': 0.10625,
#  'pa': 0.3825,
#  'ta': 0.36375,
#  'te': 0.21625}

# %% [markdown]
# 2. **Distributional Similarity**
# > Compute the KL divergence between the predicted topic distribution on the test document and the same test document in English. Lower scores are better, indicating that the distributions do not differ by much.

# %% [markdown]
# *Hindi*

# %%
# HINDI : KL Divergence for 25 topics
hi_as_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['as'])
hi_bn_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['bn'])
hi_en_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['en'])
hi_gu_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['gu'])
hi_kn_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['kn'])
hi_ml_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['ml'])
hi_mr_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['mr'])
hi_or_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['or'])
hi_pa_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['pa'])
hi_ta_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['ta'])
hi_te_kl = KLDivergence(topics_25_HI['hi'], topics_25_HI['te'])

kl_divergence_25 = {'as': hi_as_kl.score(), 'bn': hi_bn_kl.score(), 
             'en': hi_en_kl.score(), 'gu': hi_gu_kl.score(),
             'kn': hi_kn_kl.score(),
             'ml': hi_ml_kl.score(), 'mr': hi_mr_kl.score(),
             'or': hi_or_kl.score(), 'pa': hi_pa_kl.score(),
             'ta': hi_ta_kl.score(), 'te': hi_te_kl.score()}

kl_divergence_25
# Out:
# {'as': 0.21418631882747846,
#  'bn': 0.12554456053699053,
#  'en': 0.13213215643888646,
#  'gu': 0.10491287285979663,
#  'kn': 0.2057592232509147,
#  'ml': 0.25233703837194676,
#  'mr': 0.07890429517642374,
#  'or': 0.2163793272930214,
#  'pa': 0.14377184856990705,
#  'ta': 0.18361980804018363,
#  'te': 0.15718247530481724}

# %%
# HINDI : KL Divergence for 50 topics
hi_as_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['as'])
hi_bn_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['bn'])
hi_en_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['en'])
hi_gu_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['gu'])
hi_kn_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['kn'])
hi_ml_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['ml'])
hi_mr_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['mr'])
hi_or_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['or'])
hi_pa_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['pa'])
hi_ta_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['ta'])
hi_te_kl = KLDivergence(topics_50_HI['hi'], topics_50_HI['te'])

kl_divergence_50 = {'as': hi_as_kl.score(), 'bn': hi_bn_kl.score(), 
             'en': hi_en_kl.score(), 'gu': hi_gu_kl.score(),
             'kn': hi_kn_kl.score(),
             'ml': hi_ml_kl.score(), 'mr': hi_mr_kl.score(),
             'or': hi_or_kl.score(), 'pa': hi_pa_kl.score(),
             'ta': hi_ta_kl.score(), 'te': hi_te_kl.score()}

kl_divergence_50
# Out:
# {'as': 0.33664856132071214,
#  'bn': 0.16565056286805657,
#  'en': 0.14263255339547315,
#  'gu': 0.12946210087417628,
#  'kn': 0.1891453908052101,
#  'ml': 0.21693590273388097,
#  'mr': 0.09794668646263932,
#  'or': 0.40150010351315507,
#  'pa': 0.2065258857447768,
#  'ta': 0.20984083258929032,
#  'te': 0.25220701287524033}

# %% [markdown]
# *English*

# %%
# ENGLISH : KL Divergence for 25 topics
en_as_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['as'])
en_bn_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['bn'])
en_hi_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['hi'])
en_gu_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['gu'])
en_kn_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['kn'])
en_ml_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['ml'])
en_mr_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['mr'])
en_or_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['or'])
en_pa_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['pa'])
en_ta_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['ta'])
en_te_kl = KLDivergence(topics_25_EN['en'], topics_25_EN['te'])

kl_divergence_25_EN = {'as': en_as_kl.score(), 'bn': en_bn_kl.score(), 
             'hi': en_hi_kl.score(), 'gu': en_gu_kl.score(),
             'kn': en_kn_kl.score(),
             'ml': en_ml_kl.score(), 'mr': en_mr_kl.score(),
             'or': en_or_kl.score(), 'pa': en_pa_kl.score(),
             'ta': en_ta_kl.score(), 'te': en_te_kl.score()}

kl_divergence_25_EN
# Out:
# {'as': 1.0313274518450293,
#  'bn': 0.6706951475556343,
#  'gu': 0.37721976672663243,
#  'hi': 0.233475236024007,
#  'kn': 0.607528446829308,
#  'ml': 0.6483922216671271,
#  'mr': 0.2910209284263246,
#  'or': 0.8899447242015774,
#  'pa': 0.5282167309451878,
#  'ta': 0.5242024025075205,
#  'te': 0.7776165519251892}

# %%
# ENGLISH : KL Divergence for 50 topics
en_as_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['as'])
en_bn_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['bn'])
en_hi_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['hi'])
en_gu_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['gu'])
en_kn_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['kn'])
en_ml_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['ml'])
en_mr_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['mr'])
en_or_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['or'])
en_pa_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['pa'])
en_ta_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['ta'])
en_te_kl = KLDivergence(topics_50_EN['en'], topics_50_EN['te'])

kl_divergence_50_EN = {'as': en_as_kl.score(), 'bn': en_bn_kl.score(), 
             'hi': en_hi_kl.score(), 'gu': en_gu_kl.score(),
             'kn': en_kn_kl.score(),
             'ml': en_ml_kl.score(), 'mr': en_mr_kl.score(),
             'or': en_or_kl.score(), 'pa': en_pa_kl.score(),
             'ta': en_ta_kl.score(), 'te': en_te_kl.score()}

kl_divergence_50_EN
# Out:
# {'as': 1.073360061410766,
#  'bn': 0.7502772156923169,
#  'gu': 0.4397040125318557,
#  'hi': 0.2801557912564922,
#  'kn': 0.6816490982442756,
#  'ml': 0.7169776503501152,
#  'mr': 0.3532931141486461,
#  'or': 0.9813963448325722,
#  'pa': 0.5775319888935541,
#  'ta': 0.5880631427640578,
#  'te': 0.8074590934014203}

# %% [markdown]
# 3. **Centroid Embeddings**
# > To also account for similar but not exactly equal topic predictions, we compute the centroid embeddings of the 5 words describing the predicted topic for both English and non-English documents. Then we compute the cosine similarity between those two centroids (CD).

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models import KeyedVectors
import gensim.downloader as api
from scipy.spatial.distance import cosine
import abc

class CD(CentroidDistance):
    """Override author's function to upgrade compatibility with Gensim 4.0.0.
    See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4."""

    def get_centroid(self, word_list):
        vector_list = []
        for word in word_list:
            if word in self.wv:   # changed from self.wv.vocab to self.wv as in Gensim 4.0.0
                vector_list.append(self.wv.get_vector(word))
        vec = sum(vector_list)
        return vec / np.linalg.norm(vec)

# %% [markdown]
# *Hindi*

# %%
# HINDI : Centroid Embeddings for 25 topics
cd_25_HI = {}

for key in topics_25_HI.keys():
  if key == 'hi':
    continue
  topic = topics_25_HI[key]
  cd = CD(doc_distribution_original_language = topics_25_HI['hi'], 
          doc_distribution_unseen_language = topic, 
          topics = z_ctm_25_HI.get_topic_lists(25),
          topk = 5)
  
  cd_25_HI[key] = cd.score()

cd_25_HI
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# {'as': nan,
#  'bn': nan,
#  'en': nan,
#  'gu': nan,
#  'kn': nan,
#  'ml': nan,
#  'mr': nan,
#  'or': nan,
#  'pa': nan,
#  'ta': nan,
#  'te': nan}

# %%
# HINDI : Centroid Embeddings for 50 topics
cd_50_HI = {}

for key in topics_50_HI.keys():
  if key == 'hi':
    continue
  topic = topics_50_HI[key]
  cd = CD(doc_distribution_original_language = topics_50_HI['hi'], 
          doc_distribution_unseen_language = topic, 
          topics = z_ctm_50_HI.get_topic_lists(50),
          topk = 5)
  
  cd_50_HI[key] = cd.score()
  cd = None

cd_50_HI

# %% [markdown]
# *English*

# %%
# ENGLISH : Centroid Embeddings for 25 topics
cd_25_EN = {}

for key in topics_25_EN.keys():
  if key == 'en':
    continue
  topic = topics_25_EN[key]
  cd = CD(doc_distribution_original_language = topics_25_EN['en'], 
          doc_distribution_unseen_language = topic, 
          topics = z_ctm_25_EN.get_topic_lists(25),
          topk = 5)
  
  cd_25_EN[key] = cd.score()

cd_25_EN

# %%
# ENGLISH : Centroid Embeddings for 50 topics
cd_50_EN = {}

for key in topics_50_EN.keys():
  if key == 'hi':
    continue
  topic = topics_50_EN[key]
  cd = CD(doc_distribution_original_language = topics_50_EN['en'], 
          doc_distribution_unseen_language = topic, 
          topics = z_ctm_50_EN.get_topic_lists(50),
          topk = 5)
  
  cd_50_EN[key] = cd.score()
  cd = None

cd_50_EN

# %%
# Store Metrics
metrics = {
          "Hindi" : [{
                    "Mat25": matches_25_HI,
                    "KL25": kl_divergence_25_HI, 
                    "CD25": cd_25_HI, 
                    "Mat50": matches_50_HI, 
                    "KL50": kl_divergence_50_HI,
                    "CD50": cd_50_HI
                    }],

          "English": [{
                    "Mat25": matches_25_EN,
                    "KL25": kl_divergence_25_EN, 
                    "CD25": cd_25_EN, 
                    "Mat50": matches_50_EN, 
                    "KL50": kl_divergence_50_EN,
                    "CD50": cd_50_EN
                    }]
          }
with open("metrics_samescript.txt", 'wb') as F:
  pickle.dump(metrics, F)

metrics
